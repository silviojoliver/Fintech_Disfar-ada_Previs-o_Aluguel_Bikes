# %% [markdown]
# # <font color='GREY'> Uma **Fintech** Disfarçada</font>

# %% [markdown]
# ![](https://thumbs.gfycat.com/EachAgedBlackbird-small.gif)
# ![](https://s3-us-west-2.amazonaws.com/medici-prod/root/Medici/public/uploads/custom1_fintech-a-new-frontier-for-smartphone-manufacturers.gif?1607010785)

# %% [markdown]
# # 1° Problema de Negócio

# %% [markdown]
# Precisamos **Prever a demanda de aluguel de bicicletas em cada estação** do programa de compartilhamento de bicicletas, da Capital Share, em Washington, DC com base em padrões históricos de uso em relação ao clima, tempo e outros dados.
#
#
#
#
# ##### <font color='blue'> **Capital Bikeshare** </font>
# ![](https://d21xlh2maitm24.cloudfront.net/wdc/CaBi-how-it-works-hero2.jpg?mtime=20161114171736)
#
# https://www.capitalbikeshare.com/system-data
#
# ## **Como funciona esse Serviço**
# Usando esses sistemas de compartilhamento de bicicletas, as pessoas alugam uma bicicleta em um local e a devolvem em um local diferente ou no mesmo local conforme a necessidade.
#
#  As pessoas podem alugar uma bicicleta por meio de assinatura (principalmente usuários regulares) ou sob demanda (principalmente usuários casuais). Este processo é controlado por uma rede de quiosques automatizados espalhados pela cidade.

# %% [markdown]
# ## **Benefícios para os Clientes**
#
# * Nove em cada dez disseram que aderiram à Capital Bikeshare para se **locomover com mais facilidade** e rapidamente.
# * 56% dos entrevistado escolheu bikeshare porque era uma **maneira mais rápida** ou fácil de chegar ao seu destino
# * Os entrevistados relataram uma **economia média de U$ 631 por  ano** em custos de transporte pessoal como resultado do uso de bicicletas compartilhadas.

# %% [markdown]
# Capital Bikeshare
# ![](https://d21xlh2maitm24.cloudfront.net/wdc/CaBi-how-it-works-hero2.jpg?mtime=20161114171736)
#
# https://www.capitalbikeshare.com/system-data

# %% [markdown]
# ![](https://cienciadosdados.com/images/2021/Fintech/tempo.png)
# ![](https://cienciadosdados.com/images/2021/Fintech/money.png)
# ![](https://cienciadosdados.com/images/2021/Fintech/fun.png)
# ![](https://cienciadosdados.com/images/2021/Fintech/fit.png)
# ![](https://cienciadosdados.com/images/2021/Fintech/forest.png)

# %% [markdown]
# # Clube de vantagens
#
# https://www.capitalbikeshare.com/how-it-works/perks
#
# ![](https://cienciadosdados.com/images/2021/Fintech/club.png)
# ![](https://cienciadosdados.com/images/2021/Fintech/clubzip.png)
# ![](https://cienciadosdados.com/images/2021/Fintech/club_hausera.png)

# %% [markdown]
# ## **Onde a Fintech está "Escondida"**?

# %% [markdown]
# ##O Business verdadeiro são os "**DADOS**"
# ![](https://media.giphy.com/media/9A3txOMywgh87PCf5o/giphy.gif)
#
# Por meio do aplicativo bikeshare, a empresa obtém, de forma TOTALMENTE ÍNTEGRA, seus dados sobre:
#
# 1° **localização** (conhece sua rotina, seu trajeto);
#
# 2° **transações** **financeiras** (sabe qual é a bandeira do seu cartão, seu rating/pelo tipo do cartao - não é qq um que usa um infinite);
#
# 3° **Google** ou **Facebook**(por meio do google vc encontra seus clientes de forma direta);
#
# 4° **Clube de vantagens** (parceiros - ao usar 10 vc ganha x pontos para comprar na loja XyZ);
#
# 5° Angariar novos **Clientes**;
#
# 6° **Recorrencia** (planos mensais, anuais);
#
# 7° **Programa de Parcerias para Oferecer** conta corrente, investimentos, seguro, (em realtime).

# %% [markdown]
# **Observação:**
#
# Ao contrário de outros serviços de transporte, como ônibus ou metrô, a duração da viagem, posição de partida e chegada é explicitamente registrada nesses sistemas.
#
# Este recurso transforma o sistema de compartilhamento de bicicletas em uma rede de **sensores virtual** que pode ser usada para **detectar a mobilidade na cidade.**
#
# Portanto, espera-se que **a maioria dos eventos importantes na cidade possam ser detectados** por meio do monitoramento desses dados.

# %% [markdown]
# # 2° Análise Exploratória dos Dados

# %% [markdown]
# #Sacada
# Antes de explorar os dados para entender a relação entre as variáveis, recomendo que você se concentre primeiro na geração de hipóteses. Bem, isso pode parecer contra-intuitivo para resolver um problema de ciência de dados, mas se há algo que aprendi ao longo dos anos, é isso. **Antes de explorar os dados, você deve passar algum tempo pensando sobre o problema do negócio, obtendo o conhecimento do domínio e pode estar ganhando experiência em primeira mão do problema**.
#
# ## Como isso ajuda a resolver essa parada?
# Essa prática geralmente ajuda a construir o rol de variáveis para a máquina preditiva que porventura **não estejam nos disponíveis no conjunto de dados** (como faremos nesse Projeto).
#
# Nesta fase, espera-se que possua um pensamento estruturado, ou seja, um processo de pensamento que leva em consideração todos os aspectos possíveis de um problema específico.
#
# ### Aqui estão **algumas das hipóteses** que eu pensei que poderiam influenciar a demanda de bicicletas:
#
# * **Tendência dos Horários:** deve haver alta demanda durante os horários de espediente tradicional. O início da manhã e o final da noite podem ter tendências diferentes e baixa demanda durante as 22h00 às 4h00.
# * **Tendência diária**: os  usuários registrados exigem mais bicicletas durante a semana do que no fim de semana ou feriado.
# * **Chuva**: A demanda por bicicletas será menor em um dia chuvoso em comparação com um dia ensolarado. Da mesma forma, maior umidade fará com que a demanda diminua e vice-versa.
# * **Temperatura**: A temperatura pode ter uma correlação positiva dependendo do local.
# * **Poluição**: Se o nível de poluição em uma cidade começar a aumentar, as pessoas podem começar a usar a bicicleta (pode ser influenciada por políticas governamentais / da empresa ou aumento da conscientização).
# * **Tempo**:  A demanda total deve ter uma contribuição maior de usuários registrados em comparação com os casuais porque a base de usuários registrados aumentaria com o tempo.
# ***Tráfego**:  Ele  pode ser positivamente correlacionada com a demanda Bike. O tráfego intenso pode forçar as pessoas a usarem a bicicleta em comparação com outro meio de transporte rodoviário, como carro, táxi, etc.

# %% [markdown]
# # 3° Pré-Processamento dos Dados

# %%
### Importação de Bibliotecas
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Fonde de Dados - UCI
# http://archive.ics.uci.edu/ml/datasets/Bike+Sharing+Dataset

# %%
### Conectar diretamente os dados na NUVEM do Github

df_station = pd.read_csv('https://raw.githubusercontent.com/vidhi-am/tds_articles/master/AV_blogathon/Data_preparation_FeatureEngg/station_data.csv')
df_trip = pd.read_csv('https://raw.githubusercontent.com/datacodebr/tds_articles/eb2066870dad7f2708f43cab1072982fe77c4ebf/AV_blogathon/Data_preparation_FeatureEngg/trip_data.csv')
df_weather = pd.read_csv('https://raw.githubusercontent.com/vidhi-am/tds_articles/master/AV_blogathon/Data_preparation_FeatureEngg/weather_data.csv')

# %%
#Visualisar a base de dados
df_station
# Out:
#     Id                               Name        Lat        Long  Dock Count  \
# 0    2  San Jose Diridon Caltrain Station  37.329732 -121.901782          27
# 1    3              San Jose Civic Center  37.330698 -121.888979          15
# 2    4             Santa Clara at Almaden  37.333988 -121.894902          11
# 3    5                   Adobe on Almaden  37.331415 -121.893200          19
# 4    6                   San Pedro Square  37.336721 -121.894074          15
# ..  ..                                ...        ...         ...         ...
# 71  77                  Market at Sansome  37.789625 -122.400811          27
# 72  80    Santa Clara County Civic Center  37.352601 -121.905733          15
# 73  82          Broadway St at Battery St  37.798541 -122.400862          15
# 74  83                         Mezes Park  37.491269 -122.236234          15
# 75  84                        Ryland Park  37.342725 -121.895617          15
#
#              City
# 0        San Jose
# 1        San Jose
# 2        San Jose
# 3        San Jose
# 4        San Jose
# ..            ...
# 71  San Francisco
# 72       San Jose
# 73  San Francisco
# 74   Redwood City
# 75       San Jose
#
# [76 rows x 6 columns]

# %%
#Visualisar a base de dados
df_trip
# Out:
#         Trip ID        Start Date  Start Station          End Date  \
# 0        913460  31/08/2015 23:26             50  31/08/2015 23:39
# 1        913459  31/08/2015 23:11             31  31/08/2015 23:28
# 2        913455  31/08/2015 23:13             47  31/08/2015 23:18
# 3        913454  31/08/2015 23:10             10  31/08/2015 23:17
# 4        913453  31/08/2015 23:09             51  31/08/2015 23:22
# ...         ...               ...            ...               ...
# 354147   432951  01/09/2014 04:21             39  01/09/2014 04:32
# 354148   432950  01/09/2014 03:16             50  01/09/2014 05:08
# 354149   432949  01/09/2014 00:05             66  01/09/2014 00:14
# 354150   432948  01/09/2014 00:05             66  01/09/2014 00:15
# 354151   432947  01/09/2014 00:05             66  01/09/2014 00:15
#
#         End Station Subscriber Type
# 0                70      Subscriber
# 1                27      Subscriber
# 2                64      Subscriber
# 3                 8      Subscriber
# 4                60        Customer
# ...             ...             ...
# 354147           65      Subscriber
# 354148           70        Customer
# 354149           57        Customer
# 354150           57        Customer
# 354151           57        Customer
#
# [354152 rows x 6 columns]

# %%
#Visualisar a base de dados
df_weather
# Out:
#             Date  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0     01/09/2014              83.0               70.0              57.0
# 1     02/09/2014              72.0               66.0              60.0
# 2     03/09/2014              76.0               69.0              61.0
# 3     04/09/2014              74.0               68.0              61.0
# 4     05/09/2014              72.0               66.0              60.0
# ...          ...               ...                ...               ...
# 1820  27/08/2015              92.0               78.0              63.0
# 1821  28/08/2015              95.0               80.0              64.0
# 1822  29/08/2015              80.0               72.0              64.0
# 1823  30/08/2015              78.0               70.0              62.0
# 1824  31/08/2015              85.0               72.0              59.0
#
#       Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0               58.0            56.0           52.0          86.0
# 1               58.0            57.0           55.0          84.0
# 2               57.0            56.0           55.0          84.0
# 3               57.0            57.0           56.0          84.0
# 4               57.0            56.0           54.0          84.0
# ...              ...             ...            ...           ...
# 1820            57.0            51.0           40.0          78.0
# 1821            64.0            56.0           52.0          93.0
# 1822            65.0            62.0           54.0          93.0
# 1823            60.0            57.0           53.0          84.0
# 1824            59.0            55.0           51.0          84.0
#
#       Mean Humidity  Min Humidity  ...  Mean VisibilityMiles  \
# 0              64.0          42.0  ...                  10.0
# 1              73.0          61.0  ...                  10.0
# 2              69.0          53.0  ...                  10.0
# 3              71.0          57.0  ...                  10.0
# 4              71.0          57.0  ...                   9.0
# ...             ...           ...  ...                   ...
# 1820           48.0          18.0  ...                  10.0
# 1821           60.0          26.0  ...                  10.0
# 1822           70.0          47.0  ...                  10.0
# 1823           64.0          43.0  ...                  10.0
# 1824           58.0          32.0  ...                  10.0
#
#       Min VisibilityMiles  Max Wind SpeedMPH  Mean Wind SpeedMPH  \
# 0                     8.0               16.0                 7.0
# 1                     7.0               21.0                 8.0
# 2                    10.0               21.0                 8.0
# 3                     8.0               22.0                 8.0
# 4                     7.0               18.0                 8.0
# ...                   ...                ...                 ...
# 1820                 10.0               23.0                 6.0
# 1821                 10.0               25.0                 7.0
# 1822                 10.0               21.0                 9.0
# 1823                 10.0               22.0                10.0
# 1824                 10.0               20.0                 6.0
#
#       Max Gust SpeedMPH  PrecipitationIn  CloudCover  Events  WindDirDegrees  \
# 0                  20.0              0.0         0.0     NaN           290.0
# 1                   NaN              0.0         5.0     NaN           290.0
# 2                  24.0              0.0         4.0     NaN           276.0
# 3                  25.0              0.0         5.0     NaN           301.0
# 4                  32.0              0.0         4.0     NaN           309.0
# ...                 ...              ...         ...     ...             ...
# 1820               29.0              0.0         3.0     NaN           313.0
# 1821               30.0              0.0         3.0     NaN           307.0
# 1822               26.0              0.0         4.0     NaN           312.0
# 1823               29.0              0.0         3.0     NaN           291.0
# 1824               24.0              0.0         1.0     NaN           308.0
#
#         Zip
# 0     94107
# 1     94107
# 2     94107
# 3     94107
# 4     94107
# ...     ...
# 1820  95113
# 1821  95113
# 1822  95113
# 1823  95113
# 1824  95113
#
# [1825 rows x 24 columns]

# %% [markdown]
# ### Análisando os dados da Estação

# %%
df_station.head()
# Out:
#    Id                               Name        Lat        Long  Dock Count  \
# 0   2  San Jose Diridon Caltrain Station  37.329732 -121.901782          27
# 1   3              San Jose Civic Center  37.330698 -121.888979          15
# 2   4             Santa Clara at Almaden  37.333988 -121.894902          11
# 3   5                   Adobe on Almaden  37.331415 -121.893200          19
# 4   6                   San Pedro Square  37.336721 -121.894074          15
#
#        City
# 0  San Jose
# 1  San Jose
# 2  San Jose
# 3  San Jose
# 4  San Jose

# %%
df_station.shape
# Out:
# (76, 6)

# %%
### Vamos arredondar os dados de LAT e LONG pois vamos usá-los num JOIN para buscar o ZIP (codigo postal)
df_station['Lat'] = np.round(df_station['Lat'], 1)
df_station['Long'] = np.round(df_station['Long'], 1)
df_station
# Out:
#     Id                               Name   Lat   Long  Dock Count  \
# 0    2  San Jose Diridon Caltrain Station  37.3 -121.9          27
# 1    3              San Jose Civic Center  37.3 -121.9          15
# 2    4             Santa Clara at Almaden  37.3 -121.9          11
# 3    5                   Adobe on Almaden  37.3 -121.9          19
# 4    6                   San Pedro Square  37.3 -121.9          15
# ..  ..                                ...   ...    ...         ...
# 71  77                  Market at Sansome  37.8 -122.4          27
# 72  80    Santa Clara County Civic Center  37.4 -121.9          15
# 73  82          Broadway St at Battery St  37.8 -122.4          15
# 74  83                         Mezes Park  37.5 -122.2          15
# 75  84                        Ryland Park  37.3 -121.9          15
#
#              City
# 0        San Jose
# 1        San Jose
# 2        San Jose
# 3        San Jose
# 4        San Jose
# ..            ...
# 71  San Francisco
# 72       San Jose
# 73  San Francisco
# 74   Redwood City
# 75       San Jose
#
# [76 rows x 6 columns]

# %%
### Temos 71 estações de aluguel de bikes no total 
df_station.nunique()
# Out:
# Id            76
# Name          71
# Lat            4
# Long           4
# Dock Count     6
# City           5
# dtype: int64

# %%
### 5 cidades diferentes
df_station.City.unique()
# Out:
# array(['San Jose', 'Redwood City', 'Mountain View', 'Palo Alto',
#        'San Francisco'], dtype=object)

# %% [markdown]
# ### Analisando dados da Viagem (TRIP)

# %%
df_trip.head()
# Out:
#    Trip ID        Start Date  Start Station          End Date  End Station  \
# 0   913460  31/08/2015 23:26             50  31/08/2015 23:39           70
# 1   913459  31/08/2015 23:11             31  31/08/2015 23:28           27
# 2   913455  31/08/2015 23:13             47  31/08/2015 23:18           64
# 3   913454  31/08/2015 23:10             10  31/08/2015 23:17            8
# 4   913453  31/08/2015 23:09             51  31/08/2015 23:22           60
#
#   Subscriber Type
# 0      Subscriber
# 1      Subscriber
# 2      Subscriber
# 3      Subscriber
# 4        Customer

# %%
### Analisando os domínios das variáveis da tabela TRIP
df_trip.nunique()
# Out:
# Trip ID            354152
# Start Date         181944
# Start Station          76
# End Date           180406
# End Station            76
# Subscriber Type         2
# dtype: int64

# %% [markdown]
# ## Construindo a variável Target.
#
# Vamos criar a **"Net_Rate"**, que é exatamente a Taxa líquida: (viagens terminadas - viagens iniciadas) na estação, por uma determinada hora.
#
# Ex: Se numa determinada **estação** determinada **hora** finalizam 4 viagens e também se iniciam 3 viagens, nosso target(a **Net rate**) é de 1 bike.
#
# ![](https://cienciadosdados.com/images/2021/Fintech/bike.png)

# %%
#Criando a Variável Hora de início da viagem
df_trip['Start hour'] = df_trip['Start Date'].apply(lambda x: str(x).split(":")[0])
df_trip
# Out:
#         Trip ID        Start Date  Start Station          End Date  \
# 0        913460  31/08/2015 23:26             50  31/08/2015 23:39
# 1        913459  31/08/2015 23:11             31  31/08/2015 23:28
# 2        913455  31/08/2015 23:13             47  31/08/2015 23:18
# 3        913454  31/08/2015 23:10             10  31/08/2015 23:17
# 4        913453  31/08/2015 23:09             51  31/08/2015 23:22
# ...         ...               ...            ...               ...
# 354147   432951  01/09/2014 04:21             39  01/09/2014 04:32
# 354148   432950  01/09/2014 03:16             50  01/09/2014 05:08
# 354149   432949  01/09/2014 00:05             66  01/09/2014 00:14
# 354150   432948  01/09/2014 00:05             66  01/09/2014 00:15
# 354151   432947  01/09/2014 00:05             66  01/09/2014 00:15
#
#         End Station Subscriber Type     Start hour
# 0                70      Subscriber  31/08/2015 23
# 1                27      Subscriber  31/08/2015 23
# 2                64      Subscriber  31/08/2015 23
# 3                 8      Subscriber  31/08/2015 23
# 4                60        Customer  31/08/2015 23
# ...             ...             ...            ...
# 354147           65      Subscriber  01/09/2014 04
# 354148           70        Customer  01/09/2014 03
# 354149           57        Customer  01/09/2014 00
# 354150           57        Customer  01/09/2014 00
# 354151           57        Customer  01/09/2014 00
#
# [354152 rows x 7 columns]

# %%
#Criando a Variável Hora de Fim de viagem
df_trip['End hour'] = df_trip['End Date'].apply(lambda x: str(x).split(":")[0])
df_trip
# Out:
#         Trip ID        Start Date  Start Station          End Date  \
# 0        913460  31/08/2015 23:26             50  31/08/2015 23:39
# 1        913459  31/08/2015 23:11             31  31/08/2015 23:28
# 2        913455  31/08/2015 23:13             47  31/08/2015 23:18
# 3        913454  31/08/2015 23:10             10  31/08/2015 23:17
# 4        913453  31/08/2015 23:09             51  31/08/2015 23:22
# ...         ...               ...            ...               ...
# 354147   432951  01/09/2014 04:21             39  01/09/2014 04:32
# 354148   432950  01/09/2014 03:16             50  01/09/2014 05:08
# 354149   432949  01/09/2014 00:05             66  01/09/2014 00:14
# 354150   432948  01/09/2014 00:05             66  01/09/2014 00:15
# 354151   432947  01/09/2014 00:05             66  01/09/2014 00:15
#
#         End Station Subscriber Type     Start hour       End hour
# 0                70      Subscriber  31/08/2015 23  31/08/2015 23
# 1                27      Subscriber  31/08/2015 23  31/08/2015 23
# 2                64      Subscriber  31/08/2015 23  31/08/2015 23
# 3                 8      Subscriber  31/08/2015 23  31/08/2015 23
# 4                60        Customer  31/08/2015 23  31/08/2015 23
# ...             ...             ...            ...            ...
# 354147           65      Subscriber  01/09/2014 04  01/09/2014 04
# 354148           70        Customer  01/09/2014 03  01/09/2014 05
# 354149           57        Customer  01/09/2014 00  01/09/2014 00
# 354150           57        Customer  01/09/2014 00  01/09/2014 00
# 354151           57        Customer  01/09/2014 00  01/09/2014 00
#
# [354152 rows x 8 columns]

# %%
#Agrupando por Hora e Estação os valores de Início de Viagem
df_start_count = df_trip.groupby(['Start hour', 'Start Station']).count().reset_index()[['Start hour', 'Start Station', 'Trip ID']]
df_start_count
# Out:
#            Start hour  Start Station  Trip ID
# 0       01/01/2015 00             42        4
# 1       01/01/2015 00             45        1
# 2       01/01/2015 00             61        2
# 3       01/01/2015 00             62        1
# 4       01/01/2015 00             75        2
# ...               ...            ...      ...
# 142510  31/12/2014 23             39        1
# 142511  31/12/2014 23             46        2
# 142512  31/12/2014 23             54        1
# 142513  31/12/2014 23             66        2
# 142514  31/12/2014 23             73        1
#
# [142515 rows x 3 columns]

# %%
#Agrupando por Hora e Estação os valores de FIM de Viagem
df_end_count = df_trip.groupby(['End hour', 'End Station']).count().reset_index()[['End hour', 'End Station', 'Trip ID']]
df_end_count
# Out:
#              End hour  End Station  Trip ID
# 0       01/01/2015 00           47        1
# 1       01/01/2015 00           54        3
# 2       01/01/2015 00           64        1
# 3       01/01/2015 00           77        1
# 4       01/01/2015 01           56        2
# ...               ...          ...      ...
# 138660  31/12/2014 23           48        2
# 138661  31/12/2014 23           63        2
# 138662  31/12/2014 23           68        1
# 138663  31/12/2014 23           70        1
# 138664  31/12/2014 23           74        2
#
# [138665 rows x 3 columns]

# %%
#Renomeando as Colunas para fazer o MERGE ou JOIN - tabela de finalizações na estação
df_end_count.columns = ['hour', 'station', 'trip']
df_end_count
# Out:
#                  hour  station  trip
# 0       01/01/2015 00       47     1
# 1       01/01/2015 00       54     3
# 2       01/01/2015 00       64     1
# 3       01/01/2015 00       77     1
# 4       01/01/2015 01       56     2
# ...               ...      ...   ...
# 138660  31/12/2014 23       48     2
# 138661  31/12/2014 23       63     2
# 138662  31/12/2014 23       68     1
# 138663  31/12/2014 23       70     1
# 138664  31/12/2014 23       74     2
#
# [138665 rows x 3 columns]

# %%
#Renomeando as Colunas para fazer o MERGE ou JOIN - tabela de inicio de viagem na estação

df_start_count.columns = ['hour', 'station', 'trip']
df_start_count
# Out:
#                  hour  station  trip
# 0       01/01/2015 00       42     4
# 1       01/01/2015 00       45     1
# 2       01/01/2015 00       61     2
# 3       01/01/2015 00       62     1
# 4       01/01/2015 00       75     2
# ...               ...      ...   ...
# 142510  31/12/2014 23       39     1
# 142511  31/12/2014 23       46     2
# 142512  31/12/2014 23       54     1
# 142513  31/12/2014 23       66     2
# 142514  31/12/2014 23       73     1
#
# [142515 rows x 3 columns]

# %%
#Juntando as duas tabelas (MERGE ou JOIN) - inicio e finalizações
df_delta = pd.merge(df_end_count, df_start_count, on = ['hour', 'station'])
df_delta
# Out:
#                 hour  station  trip_x  trip_y
# 0      01/01/2015 01       66       4       1
# 1      01/01/2015 11       50       3       1
# 2      01/01/2015 11       68       2       2
# 3      01/01/2015 11       76       2       4
# 4      01/01/2015 12       39       2       2
# ...              ...      ...     ...     ...
# 83019  31/12/2014 18       67       1       2
# 83020  31/12/2014 18       70       1       1
# 83021  31/12/2014 18       82       1       1
# 83022  31/12/2014 19       60       2       2
# 83023  31/12/2014 22        7       1       1
#
# [83024 rows x 4 columns]

# %% [markdown]
# ### Criando o Target: Net Rate

# %%
#Net_Rate = aluguel de bikes por hora 
df_delta['net_rate'] = df_delta['trip_x'] - df_delta['trip_y'] 
df_delta
# Out:
#                 hour  station  trip_x  trip_y  net_rate
# 0      01/01/2015 01       66       4       1         3
# 1      01/01/2015 11       50       3       1         2
# 2      01/01/2015 11       68       2       2         0
# 3      01/01/2015 11       76       2       4        -2
# 4      01/01/2015 12       39       2       2         0
# ...              ...      ...     ...     ...       ...
# 83019  31/12/2014 18       67       1       2        -1
# 83020  31/12/2014 18       70       1       1         0
# 83021  31/12/2014 18       82       1       1         0
# 83022  31/12/2014 19       60       2       2         0
# 83023  31/12/2014 22        7       1       1         0
#
# [83024 rows x 5 columns]

# %%
### Detalhando as informações da data para buscar variáveis referenteso ao clima
df_delta['hour'] = pd.to_datetime(df_delta['hour'])
df_delta
# Out:
#                      hour  station  trip_x  trip_y  net_rate
# 0     2015-01-01 01:00:00       66       4       1         3
# 1     2015-01-01 11:00:00       50       3       1         2
# 2     2015-01-01 11:00:00       68       2       2         0
# 3     2015-01-01 11:00:00       76       2       4        -2
# 4     2015-01-01 12:00:00       39       2       2         0
# ...                   ...      ...     ...     ...       ...
# 83019 2014-12-31 18:00:00       67       1       2        -1
# 83020 2014-12-31 18:00:00       70       1       1         0
# 83021 2014-12-31 18:00:00       82       1       1         0
# 83022 2014-12-31 19:00:00       60       2       2         0
# 83023 2014-12-31 22:00:00        7       1       1         0
#
# [83024 rows x 5 columns]

# %%
# Cria uma coluna de data separada do timestamp
df_delta['date']  = (df_delta['hour']).apply(lambda x: x.date())
df_delta
# Out:
#                      hour  station  trip_x  trip_y  net_rate        date
# 0     2015-01-01 01:00:00       66       4       1         3  2015-01-01
# 1     2015-01-01 11:00:00       50       3       1         2  2015-01-01
# 2     2015-01-01 11:00:00       68       2       2         0  2015-01-01
# 3     2015-01-01 11:00:00       76       2       4        -2  2015-01-01
# 4     2015-01-01 12:00:00       39       2       2         0  2015-01-01
# ...                   ...      ...     ...     ...       ...         ...
# 83019 2014-12-31 18:00:00       67       1       2        -1  2014-12-31
# 83020 2014-12-31 18:00:00       70       1       1         0  2014-12-31
# 83021 2014-12-31 18:00:00       82       1       1         0  2014-12-31
# 83022 2014-12-31 19:00:00       60       2       2         0  2014-12-31
# 83023 2014-12-31 22:00:00        7       1       1         0  2014-12-31
#
# [83024 rows x 6 columns]

# %%
### Left Join entre as tabelas "net rate" e station
df_station_netrate = df_delta.merge(df_station, left_on = 'station', right_on = 'Id', how = 'left')

# %%
df_station_netrate.head()
# Out:
#                  hour  station  trip_x  trip_y  net_rate        date  Id  \
# 0 2015-01-01 01:00:00       66       4       1         3  2015-01-01  66
# 1 2015-01-01 11:00:00       50       3       1         2  2015-01-01  50
# 2 2015-01-01 11:00:00       68       2       2         0  2015-01-01  68
# 3 2015-01-01 11:00:00       76       2       4        -2  2015-01-01  76
# 4 2015-01-01 12:00:00       39       2       2         0  2015-01-01  39
#
#                                             Name   Lat   Long  Dock Count  \
# 0                       South Van Ness at Market  37.8 -122.4          19
# 1           Harry Bridges Plaza (Ferry Building)  37.8 -122.4          23
# 2  Yerba Buena Center of the Arts (3rd @ Howard)  37.8 -122.4          19
# 3                                  Market at 4th  37.8 -122.4          19
# 4                             Powell Street BART  37.8 -122.4          19
#
#             City
# 0  San Francisco
# 1  San Francisco
# 2  San Francisco
# 3  San Francisco
# 4  San Francisco

# %% [markdown]
# ### Analisando dados do Clima (Weather)

# %%
df_weather.head()
# Out:
#          Date  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0  01/09/2014              83.0               70.0              57.0
# 1  02/09/2014              72.0               66.0              60.0
# 2  03/09/2014              76.0               69.0              61.0
# 3  04/09/2014              74.0               68.0              61.0
# 4  05/09/2014              72.0               66.0              60.0
#
#    Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  Mean Humidity  \
# 0            58.0            56.0           52.0          86.0           64.0
# 1            58.0            57.0           55.0          84.0           73.0
# 2            57.0            56.0           55.0          84.0           69.0
# 3            57.0            57.0           56.0          84.0           71.0
# 4            57.0            56.0           54.0          84.0           71.0
#
#    Min Humidity  ...  Mean VisibilityMiles  Min VisibilityMiles  \
# 0          42.0  ...                  10.0                  8.0
# 1          61.0  ...                  10.0                  7.0
# 2          53.0  ...                  10.0                 10.0
# 3          57.0  ...                  10.0                  8.0
# 4          57.0  ...                   9.0                  7.0
#
#    Max Wind SpeedMPH  Mean Wind SpeedMPH  Max Gust SpeedMPH  PrecipitationIn  \
# 0               16.0                 7.0               20.0              0.0
# 1               21.0                 8.0                NaN              0.0
# 2               21.0                 8.0               24.0              0.0
# 3               22.0                 8.0               25.0              0.0
# 4               18.0                 8.0               32.0              0.0
#
#    CloudCover  Events  WindDirDegrees    Zip
# 0         0.0     NaN           290.0  94107
# 1         5.0     NaN           290.0  94107
# 2         4.0     NaN           276.0  94107
# 3         5.0     NaN           301.0  94107
# 4         4.0     NaN           309.0  94107
#
# [5 rows x 24 columns]

# %%
### Verifique as colunas: temos recursos estatísticos, ou seja, mínimo, máximo e mínimo dos principais atributos do clima, como: temperatura, pressão, umidade, etc.
df_weather.columns
# Out:
# Index(['Date', 'Max TemperatureF', 'Mean TemperatureF', 'Min TemperatureF',
#        'Max Dew PointF', 'MeanDew PointF', 'Min DewpointF', 'Max Humidity',
#        'Mean Humidity', 'Min Humidity', 'Max Sea Level PressureIn',
#        'Mean Sea Level PressureIn', 'Min Sea Level PressureIn',
#        'Max VisibilityMiles', 'Mean VisibilityMiles', 'Min VisibilityMiles',
#        'Max Wind SpeedMPH', 'Mean Wind SpeedMPH', 'Max Gust SpeedMPH',
#        'PrecipitationIn', 'CloudCover', 'Events', 'WindDirDegrees', 'Zip'],
#       dtype='object')

# %%
### Vamos verificar as estatísticas resumidas para recursos meteorológico
df_weather.describe().T
# Out:
#                             count          mean         std       min  \
# Max TemperatureF           1821.0     70.637013    8.260028     50.00
# Mean TemperatureF          1821.0     61.837452    6.893216     41.00
# Min TemperatureF           1821.0     52.733663    7.037803     30.00
# Max Dew PointF             1775.0     54.460845    6.330125     20.00
# MeanDew PointF             1775.0     50.397183    7.101097     13.00
# Min DewpointF              1775.0     46.135775    8.548960      4.00
# Max Humidity               1775.0     87.505915    8.537459     25.00
# Mean Humidity              1775.0     69.282817   10.408295     25.00
# Min Humidity               1775.0     48.769014   14.274316      4.00
# Max Sea Level PressureIn   1824.0     30.070641    0.135416     29.67
# Mean Sea Level PressureIn  1824.0     30.017144    0.131222     29.63
# Min Sea Level PressureIn   1824.0     29.962659    0.132534     29.34
# Max VisibilityMiles        1820.0     10.475275    2.083719      5.00
# Mean VisibilityMiles       1820.0      9.636813    1.433697      4.00
# Min VisibilityMiles        1820.0      7.948901    2.993878      0.00
# Max Wind SpeedMPH          1824.0     16.347588    8.592296      4.00
# Mean Wind SpeedMPH         1824.0      6.150219    3.238621      0.00
# Max Gust SpeedMPH          1284.0     21.690810    6.052399      7.00
# PrecipitationIn            1824.0      0.025032    0.177212      0.00
# CloudCover                 1824.0      3.110746    2.297131      0.00
# WindDirDegrees             1824.0    260.584430   95.985517      0.00
# Zip                        1825.0  94325.000000  404.670892  94041.00
#
#                                 25%       50%       75%       max
# Max TemperatureF              64.00     70.00     76.00    102.00
# Mean TemperatureF             57.00     61.00     67.00     82.00
# Min TemperatureF              48.00     53.00     58.00     75.00
# Max Dew PointF                50.00     55.00     59.00     68.00
# MeanDew PointF                47.00     51.00     56.00     64.00
# Min DewpointF                 41.00     48.00     53.00     63.00
# Max Humidity                  83.00     88.00     93.00    100.00
# Mean Humidity                 64.00     70.00     75.00     96.00
# Min Humidity                  40.00     50.00     57.00     86.00
# Max Sea Level PressureIn      29.97     30.05     30.17     30.48
# Mean Sea Level PressureIn     29.92     30.00     30.11     30.41
# Min Sea Level PressureIn      29.87     29.95     30.05     30.36
# Max VisibilityMiles           10.00     10.00     10.00     20.00
# Mean VisibilityMiles          10.00     10.00     10.00     20.00
# Min VisibilityMiles            6.00     10.00     10.00     20.00
# Max Wind SpeedMPH             12.00     16.00     20.00    128.00
# Mean Wind SpeedMPH             4.00      6.00      8.00     23.00
# Max Gust SpeedMPH             18.00     22.00     25.00     62.00
# PrecipitationIn                0.00      0.00      0.00      3.36
# CloudCover                     1.00      3.00      5.00      8.00
# WindDirDegrees               242.00    295.00    328.00    360.00
# Zip                        94063.00  94107.00  94301.00  95113.00

# %%
#Dimensões da tabela
df_weather.shape
# Out:
# (1825, 24)

# %%
### Verifica Missings nos campos (Eventos tem muito missing)
df_weather.isnull().sum()
# Out:
# Date                            0
# Max TemperatureF                4
# Mean TemperatureF               4
# Min TemperatureF                4
# Max Dew PointF                 50
# MeanDew PointF                 50
# Min DewpointF                  50
# Max Humidity                   50
# Mean Humidity                  50
# Min Humidity                   50
# Max Sea Level PressureIn        1
# Mean Sea Level PressureIn       1
# Min Sea Level PressureIn        1
# Max VisibilityMiles             5
# Mean VisibilityMiles            5
# Min VisibilityMiles             5
# Max Wind SpeedMPH               1
# Mean Wind SpeedMPH              1
# Max Gust SpeedMPH             541
# PrecipitationIn                 1
# CloudCover                      1
# Events                       1538
# WindDirDegrees                  1
# Zip                             0
# dtype: int64

# %%
### Vamos verificar mais sobre este recurso: Eventos
df_weather['Events'].unique()
# Out:
# array([nan, 'Rain', 'Fog', 'Fog-Rain', 'Rain-Thunderstorm'], dtype=object)

# %%
### apenas alguns eventos capturados sob Rain, Fog e Fog-Rain têm detalhes do clima
df_weather['Events'].value_counts()
# Out:
# Rain                 195
# Fog                   73
# Fog-Rain              16
# Rain-Thunderstorm      3
# Name: Events, dtype: int64

# %% [markdown]
# ### Precisamos de Dados externos de lat e long para fazer o Join e usar código postal ZIP para mesclar o df_weather com  a tabela de variáveis das estações "df_station"

# %%
df_weather.describe().T
# Out:
#                             count          mean         std       min  \
# Max TemperatureF           1821.0     70.637013    8.260028     50.00
# Mean TemperatureF          1821.0     61.837452    6.893216     41.00
# Min TemperatureF           1821.0     52.733663    7.037803     30.00
# Max Dew PointF             1775.0     54.460845    6.330125     20.00
# MeanDew PointF             1775.0     50.397183    7.101097     13.00
# Min DewpointF              1775.0     46.135775    8.548960      4.00
# Max Humidity               1775.0     87.505915    8.537459     25.00
# Mean Humidity              1775.0     69.282817   10.408295     25.00
# Min Humidity               1775.0     48.769014   14.274316      4.00
# Max Sea Level PressureIn   1824.0     30.070641    0.135416     29.67
# Mean Sea Level PressureIn  1824.0     30.017144    0.131222     29.63
# Min Sea Level PressureIn   1824.0     29.962659    0.132534     29.34
# Max VisibilityMiles        1820.0     10.475275    2.083719      5.00
# Mean VisibilityMiles       1820.0      9.636813    1.433697      4.00
# Min VisibilityMiles        1820.0      7.948901    2.993878      0.00
# Max Wind SpeedMPH          1824.0     16.347588    8.592296      4.00
# Mean Wind SpeedMPH         1824.0      6.150219    3.238621      0.00
# Max Gust SpeedMPH          1284.0     21.690810    6.052399      7.00
# PrecipitationIn            1824.0      0.025032    0.177212      0.00
# CloudCover                 1824.0      3.110746    2.297131      0.00
# WindDirDegrees             1824.0    260.584430   95.985517      0.00
# Zip                        1825.0  94325.000000  404.670892  94041.00
#
#                                 25%       50%       75%       max
# Max TemperatureF              64.00     70.00     76.00    102.00
# Mean TemperatureF             57.00     61.00     67.00     82.00
# Min TemperatureF              48.00     53.00     58.00     75.00
# Max Dew PointF                50.00     55.00     59.00     68.00
# MeanDew PointF                47.00     51.00     56.00     64.00
# Min DewpointF                 41.00     48.00     53.00     63.00
# Max Humidity                  83.00     88.00     93.00    100.00
# Mean Humidity                 64.00     70.00     75.00     96.00
# Min Humidity                  40.00     50.00     57.00     86.00
# Max Sea Level PressureIn      29.97     30.05     30.17     30.48
# Mean Sea Level PressureIn     29.92     30.00     30.11     30.41
# Min Sea Level PressureIn      29.87     29.95     30.05     30.36
# Max VisibilityMiles           10.00     10.00     10.00     20.00
# Mean VisibilityMiles          10.00     10.00     10.00     20.00
# Min VisibilityMiles            6.00     10.00     10.00     20.00
# Max Wind SpeedMPH             12.00     16.00     20.00    128.00
# Mean Wind SpeedMPH             4.00      6.00      8.00     23.00
# Max Gust SpeedMPH             18.00     22.00     25.00     62.00
# PrecipitationIn                0.00      0.00      0.00      3.36
# CloudCover                     1.00      3.00      5.00      8.00
# WindDirDegrees               242.00    295.00    328.00    360.00
# Zip                        94063.00  94107.00  94301.00  95113.00

# %%
df_station.describe().T
# Out:
#             count        mean        std    min     25%    50%     75%    max
# Id           76.0   46.513158  26.142427    2.0   25.75   47.5   68.25   90.0
# Lat          76.0   37.597368   0.216625   37.3   37.40   37.8   37.80   37.8
# Long         76.0 -122.227632   0.201063 -122.4 -122.40 -122.4 -122.10 -121.9
# Dock Count   76.0   17.815789   4.015671   11.0   15.00   15.0   19.00   27.0

# %% [markdown]
# ### Buscamos dataset Público com informações de Lat e Long e ZIP
# https://public.opendatasoft.com/explore/dataset/us-zip-code-latitude-and-longitude/export/

# %%
### Buscando dados do site: https://public.opendatasoft.com/explore/dataset/us-zip-code-latitude-and-longitude/export/
#-longitude.csv')
zip_to_latlong = pd.read_csv('https://raw.githubusercontent.com/vidhi-am/tds_articles/master/AV_blogathon/Data_preparation_FeatureEngg/us-zip-code-latitude-and-longitude.csv', sep=';')
zip_to_latlong
# Out:
#          Zip        City State   Latitude   Longitude  Timezone  \
# 0      67553  Liebenthal    KS  38.654948  -99.320620        -6
# 1      85743      Tucson    AZ  32.335122 -111.148880        -7
# 2      75016      Irving    TX  32.767268  -96.777626        -6
# 3      60401     Beecher    IL  41.350484  -87.624080        -6
# 4      80432        Como    CO  39.243440 -105.794310        -7
# ...      ...         ...   ...        ...         ...       ...
# 43186  50157      Malcom    IA  41.738800  -92.561550        -6
# 43187  65212    Columbia    MO  38.937608  -92.330430        -6
# 43188  11935   Cutchogue    NY  41.012868  -72.472300        -5
# 43189  63539       Ethel    MO  39.893011  -92.745030        -6
# 43190  39051    Carthage    MS  32.785139  -89.506440        -6
#
#        Daylight savings time flag              geopoint
# 0                               1   38.654948,-99.32062
# 1                               0  32.335122,-111.14888
# 2                               1  32.767268,-96.777626
# 3                               1   41.350484,-87.62408
# 4                               1   39.24344,-105.79431
# ...                           ...                   ...
# 43186                           1     41.7388,-92.56155
# 43187                           1   38.937608,-92.33043
# 43188                           1    41.012868,-72.4723
# 43189                           1   39.893011,-92.74503
# 43190                           1   32.785139,-89.50644
#
# [43191 rows x 8 columns]

# %%
### Para todas as cidades relevantes apresentadas nos dados da df_station, obtenha as informações mais longas com o zip correspondente
zip_to_latlong = zip_to_latlong[zip_to_latlong.City.isin(df_station.City.unique())]

### Filtrando somente as colunas que vamos usar
zip_to_latlong = zip_to_latlong[['Zip', 'Latitude', 'Longitude']]

# %%
#View na tabela
zip_to_latlong.head()
# Out:
#         Zip   Latitude   Longitude
# 88    94156  37.784827 -122.727802
# 523   95159  37.189396 -121.705327
# 774   94303  37.449888 -122.127490
# 1427  94142  37.784827 -122.727802
# 1706  94122  37.758380 -122.484780

# %%
### Agora sim, juntamos (Merging) os dados de clima com os dados externos para juntar aos dados da estação e da viagem no nível de data
df_weather_latlong = df_weather.merge(zip_to_latlong, on = 'Zip', how = 'left')
df_weather_latlong
# Out:
#             Date  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0     01/09/2014              83.0               70.0              57.0
# 1     02/09/2014              72.0               66.0              60.0
# 2     03/09/2014              76.0               69.0              61.0
# 3     04/09/2014              74.0               68.0              61.0
# 4     05/09/2014              72.0               66.0              60.0
# ...          ...               ...                ...               ...
# 1820  27/08/2015              92.0               78.0              63.0
# 1821  28/08/2015              95.0               80.0              64.0
# 1822  29/08/2015              80.0               72.0              64.0
# 1823  30/08/2015              78.0               70.0              62.0
# 1824  31/08/2015              85.0               72.0              59.0
#
#       Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0               58.0            56.0           52.0          86.0
# 1               58.0            57.0           55.0          84.0
# 2               57.0            56.0           55.0          84.0
# 3               57.0            57.0           56.0          84.0
# 4               57.0            56.0           54.0          84.0
# ...              ...             ...            ...           ...
# 1820            57.0            51.0           40.0          78.0
# 1821            64.0            56.0           52.0          93.0
# 1822            65.0            62.0           54.0          93.0
# 1823            60.0            57.0           53.0          84.0
# 1824            59.0            55.0           51.0          84.0
#
#       Mean Humidity  Min Humidity  ...  Max Wind SpeedMPH  Mean Wind SpeedMPH  \
# 0              64.0          42.0  ...               16.0                 7.0
# 1              73.0          61.0  ...               21.0                 8.0
# 2              69.0          53.0  ...               21.0                 8.0
# 3              71.0          57.0  ...               22.0                 8.0
# 4              71.0          57.0  ...               18.0                 8.0
# ...             ...           ...  ...                ...                 ...
# 1820           48.0          18.0  ...               23.0                 6.0
# 1821           60.0          26.0  ...               25.0                 7.0
# 1822           70.0          47.0  ...               21.0                 9.0
# 1823           64.0          43.0  ...               22.0                10.0
# 1824           58.0          32.0  ...               20.0                 6.0
#
#       Max Gust SpeedMPH  PrecipitationIn  CloudCover  Events  WindDirDegrees  \
# 0                  20.0              0.0         0.0     NaN           290.0
# 1                   NaN              0.0         5.0     NaN           290.0
# 2                  24.0              0.0         4.0     NaN           276.0
# 3                  25.0              0.0         5.0     NaN           301.0
# 4                  32.0              0.0         4.0     NaN           309.0
# ...                 ...              ...         ...     ...             ...
# 1820               29.0              0.0         3.0     NaN           313.0
# 1821               30.0              0.0         3.0     NaN           307.0
# 1822               26.0              0.0         4.0     NaN           312.0
# 1823               29.0              0.0         3.0     NaN           291.0
# 1824               24.0              0.0         1.0     NaN           308.0
#
#         Zip   Latitude  Longitude
# 0     94107  37.766529 -122.39577
# 1     94107  37.766529 -122.39577
# 2     94107  37.766529 -122.39577
# 3     94107  37.766529 -122.39577
# 4     94107  37.766529 -122.39577
# ...     ...        ...        ...
# 1820  95113  37.333941 -121.89154
# 1821  95113  37.333941 -121.89154
# 1822  95113  37.333941 -121.89154
# 1823  95113  37.333941 -121.89154
# 1824  95113  37.333941 -121.89154
#
# [1825 rows x 26 columns]

# %%
### Arredondando para fazer o Merging
df_weather_latlong['Latitude'] = np.round(df_weather_latlong['Latitude'], 1)
df_weather_latlong
# Out:
#             Date  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0     01/09/2014              83.0               70.0              57.0
# 1     02/09/2014              72.0               66.0              60.0
# 2     03/09/2014              76.0               69.0              61.0
# 3     04/09/2014              74.0               68.0              61.0
# 4     05/09/2014              72.0               66.0              60.0
# ...          ...               ...                ...               ...
# 1820  27/08/2015              92.0               78.0              63.0
# 1821  28/08/2015              95.0               80.0              64.0
# 1822  29/08/2015              80.0               72.0              64.0
# 1823  30/08/2015              78.0               70.0              62.0
# 1824  31/08/2015              85.0               72.0              59.0
#
#       Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0               58.0            56.0           52.0          86.0
# 1               58.0            57.0           55.0          84.0
# 2               57.0            56.0           55.0          84.0
# 3               57.0            57.0           56.0          84.0
# 4               57.0            56.0           54.0          84.0
# ...              ...             ...            ...           ...
# 1820            57.0            51.0           40.0          78.0
# 1821            64.0            56.0           52.0          93.0
# 1822            65.0            62.0           54.0          93.0
# 1823            60.0            57.0           53.0          84.0
# 1824            59.0            55.0           51.0          84.0
#
#       Mean Humidity  Min Humidity  ...  Max Wind SpeedMPH  Mean Wind SpeedMPH  \
# 0              64.0          42.0  ...               16.0                 7.0
# 1              73.0          61.0  ...               21.0                 8.0
# 2              69.0          53.0  ...               21.0                 8.0
# 3              71.0          57.0  ...               22.0                 8.0
# 4              71.0          57.0  ...               18.0                 8.0
# ...             ...           ...  ...                ...                 ...
# 1820           48.0          18.0  ...               23.0                 6.0
# 1821           60.0          26.0  ...               25.0                 7.0
# 1822           70.0          47.0  ...               21.0                 9.0
# 1823           64.0          43.0  ...               22.0                10.0
# 1824           58.0          32.0  ...               20.0                 6.0
#
#       Max Gust SpeedMPH  PrecipitationIn  CloudCover  Events  WindDirDegrees  \
# 0                  20.0              0.0         0.0     NaN           290.0
# 1                   NaN              0.0         5.0     NaN           290.0
# 2                  24.0              0.0         4.0     NaN           276.0
# 3                  25.0              0.0         5.0     NaN           301.0
# 4                  32.0              0.0         4.0     NaN           309.0
# ...                 ...              ...         ...     ...             ...
# 1820               29.0              0.0         3.0     NaN           313.0
# 1821               30.0              0.0         3.0     NaN           307.0
# 1822               26.0              0.0         4.0     NaN           312.0
# 1823               29.0              0.0         3.0     NaN           291.0
# 1824               24.0              0.0         1.0     NaN           308.0
#
#         Zip  Latitude  Longitude
# 0     94107      37.8 -122.39577
# 1     94107      37.8 -122.39577
# 2     94107      37.8 -122.39577
# 3     94107      37.8 -122.39577
# 4     94107      37.8 -122.39577
# ...     ...       ...        ...
# 1820  95113      37.3 -121.89154
# 1821  95113      37.3 -121.89154
# 1822  95113      37.3 -121.89154
# 1823  95113      37.3 -121.89154
# 1824  95113      37.3 -121.89154
#
# [1825 rows x 26 columns]

# %%
df_weather_latlong['Longitude'] = np.round(df_weather_latlong['Longitude'], 1)
df_weather_latlong
# Out:
#             Date  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0     01/09/2014              83.0               70.0              57.0
# 1     02/09/2014              72.0               66.0              60.0
# 2     03/09/2014              76.0               69.0              61.0
# 3     04/09/2014              74.0               68.0              61.0
# 4     05/09/2014              72.0               66.0              60.0
# ...          ...               ...                ...               ...
# 1820  27/08/2015              92.0               78.0              63.0
# 1821  28/08/2015              95.0               80.0              64.0
# 1822  29/08/2015              80.0               72.0              64.0
# 1823  30/08/2015              78.0               70.0              62.0
# 1824  31/08/2015              85.0               72.0              59.0
#
#       Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0               58.0            56.0           52.0          86.0
# 1               58.0            57.0           55.0          84.0
# 2               57.0            56.0           55.0          84.0
# 3               57.0            57.0           56.0          84.0
# 4               57.0            56.0           54.0          84.0
# ...              ...             ...            ...           ...
# 1820            57.0            51.0           40.0          78.0
# 1821            64.0            56.0           52.0          93.0
# 1822            65.0            62.0           54.0          93.0
# 1823            60.0            57.0           53.0          84.0
# 1824            59.0            55.0           51.0          84.0
#
#       Mean Humidity  Min Humidity  ...  Max Wind SpeedMPH  Mean Wind SpeedMPH  \
# 0              64.0          42.0  ...               16.0                 7.0
# 1              73.0          61.0  ...               21.0                 8.0
# 2              69.0          53.0  ...               21.0                 8.0
# 3              71.0          57.0  ...               22.0                 8.0
# 4              71.0          57.0  ...               18.0                 8.0
# ...             ...           ...  ...                ...                 ...
# 1820           48.0          18.0  ...               23.0                 6.0
# 1821           60.0          26.0  ...               25.0                 7.0
# 1822           70.0          47.0  ...               21.0                 9.0
# 1823           64.0          43.0  ...               22.0                10.0
# 1824           58.0          32.0  ...               20.0                 6.0
#
#       Max Gust SpeedMPH  PrecipitationIn  CloudCover  Events  WindDirDegrees  \
# 0                  20.0              0.0         0.0     NaN           290.0
# 1                   NaN              0.0         5.0     NaN           290.0
# 2                  24.0              0.0         4.0     NaN           276.0
# 3                  25.0              0.0         5.0     NaN           301.0
# 4                  32.0              0.0         4.0     NaN           309.0
# ...                 ...              ...         ...     ...             ...
# 1820               29.0              0.0         3.0     NaN           313.0
# 1821               30.0              0.0         3.0     NaN           307.0
# 1822               26.0              0.0         4.0     NaN           312.0
# 1823               29.0              0.0         3.0     NaN           291.0
# 1824               24.0              0.0         1.0     NaN           308.0
#
#         Zip  Latitude  Longitude
# 0     94107      37.8     -122.4
# 1     94107      37.8     -122.4
# 2     94107      37.8     -122.4
# 3     94107      37.8     -122.4
# 4     94107      37.8     -122.4
# ...     ...       ...        ...
# 1820  95113      37.3     -121.9
# 1821  95113      37.3     -121.9
# 1822  95113      37.3     -121.9
# 1823  95113      37.3     -121.9
# 1824  95113      37.3     -121.9
#
# [1825 rows x 26 columns]

# %%
df_weather_latlong.head()
# Out:
#          Date  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0  01/09/2014              83.0               70.0              57.0
# 1  02/09/2014              72.0               66.0              60.0
# 2  03/09/2014              76.0               69.0              61.0
# 3  04/09/2014              74.0               68.0              61.0
# 4  05/09/2014              72.0               66.0              60.0
#
#    Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  Mean Humidity  \
# 0            58.0            56.0           52.0          86.0           64.0
# 1            58.0            57.0           55.0          84.0           73.0
# 2            57.0            56.0           55.0          84.0           69.0
# 3            57.0            57.0           56.0          84.0           71.0
# 4            57.0            56.0           54.0          84.0           71.0
#
#    Min Humidity  ...  Max Wind SpeedMPH  Mean Wind SpeedMPH  \
# 0          42.0  ...               16.0                 7.0
# 1          61.0  ...               21.0                 8.0
# 2          53.0  ...               21.0                 8.0
# 3          57.0  ...               22.0                 8.0
# 4          57.0  ...               18.0                 8.0
#
#    Max Gust SpeedMPH  PrecipitationIn  CloudCover  Events  WindDirDegrees  \
# 0               20.0              0.0         0.0     NaN           290.0
# 1                NaN              0.0         5.0     NaN           290.0
# 2               24.0              0.0         4.0     NaN           276.0
# 3               25.0              0.0         5.0     NaN           301.0
# 4               32.0              0.0         4.0     NaN           309.0
#
#      Zip  Latitude  Longitude
# 0  94107      37.8     -122.4
# 1  94107      37.8     -122.4
# 2  94107      37.8     -122.4
# 3  94107      37.8     -122.4
# 4  94107      37.8     -122.4
#
# [5 rows x 26 columns]

# %%
df_weather_latlong.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1825 entries, 0 to 1824
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       1825 non-null   object
#  1   Max TemperatureF           1821 non-null   float64
#  2   Mean TemperatureF          1821 non-null   float64
#  3   Min TemperatureF           1821 non-null   float64
#  4   Max Dew PointF             1775 non-null   float64
#  5   MeanDew PointF             1775 non-null   float64
#  6   Min DewpointF              1775 non-null   float64
#  7   Max Humidity               1775 non-null   float64
#  8   Mean Humidity              1775 non-null   float64
#  9   Min Humidity               1775 non-null   float64
#  10  Max Sea Level PressureIn   1824 non-null   float64
#  11  Mean Sea Level PressureIn  1824 non-null   float64
#  12  Min Sea Level PressureIn   1824 non-null   float64
#  13  Max VisibilityMiles        1820 non-null   float64
#  14  Mean VisibilityMiles       1820 non-null   float64
#  15  Min VisibilityMiles        1820 non-null   float64
#  16  Max Wind SpeedMPH          1824 non-null   float64
#  17  Mean Wind SpeedMPH         1824 non-null   float64
#  18  Max Gust SpeedMPH          1284 non-null   float64
#  19  PrecipitationIn            1824 non-null   float64
#  20  CloudCover                 1824 non-null   float64
#  21  Events                     287 non-null    object
#  22  WindDirDegrees             1824 non-null   float64
#  23  Zip                        1825 non-null   int64
#  24  Latitude                   1825 non-null   float64
#  25  Longitude                  1825 non-null   float64
# dtypes: float64(23), int64(1), object(2)
# memory usage: 385.0+ KB

# %%
df_station.shape
# Out:
# (76, 6)

# %% [markdown]
# Correção de tipo de data para mesclagem apropriada

# %%
df_weather_latlong['Date']  = pd.to_datetime(df_weather_latlong['Date'])
df_weather_latlong
# Out:
#            Date  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0    2014-01-09              83.0               70.0              57.0
# 1    2014-02-09              72.0               66.0              60.0
# 2    2014-03-09              76.0               69.0              61.0
# 3    2014-04-09              74.0               68.0              61.0
# 4    2014-05-09              72.0               66.0              60.0
# ...         ...               ...                ...               ...
# 1820 2015-08-27              92.0               78.0              63.0
# 1821 2015-08-28              95.0               80.0              64.0
# 1822 2015-08-29              80.0               72.0              64.0
# 1823 2015-08-30              78.0               70.0              62.0
# 1824 2015-08-31              85.0               72.0              59.0
#
#       Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0               58.0            56.0           52.0          86.0
# 1               58.0            57.0           55.0          84.0
# 2               57.0            56.0           55.0          84.0
# 3               57.0            57.0           56.0          84.0
# 4               57.0            56.0           54.0          84.0
# ...              ...             ...            ...           ...
# 1820            57.0            51.0           40.0          78.0
# 1821            64.0            56.0           52.0          93.0
# 1822            65.0            62.0           54.0          93.0
# 1823            60.0            57.0           53.0          84.0
# 1824            59.0            55.0           51.0          84.0
#
#       Mean Humidity  Min Humidity  ...  Max Wind SpeedMPH  Mean Wind SpeedMPH  \
# 0              64.0          42.0  ...               16.0                 7.0
# 1              73.0          61.0  ...               21.0                 8.0
# 2              69.0          53.0  ...               21.0                 8.0
# 3              71.0          57.0  ...               22.0                 8.0
# 4              71.0          57.0  ...               18.0                 8.0
# ...             ...           ...  ...                ...                 ...
# 1820           48.0          18.0  ...               23.0                 6.0
# 1821           60.0          26.0  ...               25.0                 7.0
# 1822           70.0          47.0  ...               21.0                 9.0
# 1823           64.0          43.0  ...               22.0                10.0
# 1824           58.0          32.0  ...               20.0                 6.0
#
#       Max Gust SpeedMPH  PrecipitationIn  CloudCover  Events  WindDirDegrees  \
# 0                  20.0              0.0         0.0     NaN           290.0
# 1                   NaN              0.0         5.0     NaN           290.0
# 2                  24.0              0.0         4.0     NaN           276.0
# 3                  25.0              0.0         5.0     NaN           301.0
# 4                  32.0              0.0         4.0     NaN           309.0
# ...                 ...              ...         ...     ...             ...
# 1820               29.0              0.0         3.0     NaN           313.0
# 1821               30.0              0.0         3.0     NaN           307.0
# 1822               26.0              0.0         4.0     NaN           312.0
# 1823               29.0              0.0         3.0     NaN           291.0
# 1824               24.0              0.0         1.0     NaN           308.0
#
#         Zip  Latitude  Longitude
# 0     94107      37.8     -122.4
# 1     94107      37.8     -122.4
# 2     94107      37.8     -122.4
# 3     94107      37.8     -122.4
# 4     94107      37.8     -122.4
# ...     ...       ...        ...
# 1820  95113      37.3     -121.9
# 1821  95113      37.3     -121.9
# 1822  95113      37.3     -121.9
# 1823  95113      37.3     -121.9
# 1824  95113      37.3     -121.9
#
# [1825 rows x 26 columns]

# %%
df_station_netrate['date'] = pd.to_datetime(df_station_netrate['date'])
df_station_netrate
# Out:
#                      hour  station  trip_x  trip_y  net_rate       date  Id  \
# 0     2015-01-01 01:00:00       66       4       1         3 2015-01-01  66
# 1     2015-01-01 11:00:00       50       3       1         2 2015-01-01  50
# 2     2015-01-01 11:00:00       68       2       2         0 2015-01-01  68
# 3     2015-01-01 11:00:00       76       2       4        -2 2015-01-01  76
# 4     2015-01-01 12:00:00       39       2       2         0 2015-01-01  39
# ...                   ...      ...     ...     ...       ...        ...  ..
# 83019 2014-12-31 18:00:00       67       1       2        -1 2014-12-31  67
# 83020 2014-12-31 18:00:00       70       1       1         0 2014-12-31  70
# 83021 2014-12-31 18:00:00       82       1       1         0 2014-12-31  82
# 83022 2014-12-31 19:00:00       60       2       2         0 2014-12-31  60
# 83023 2014-12-31 22:00:00        7       1       1         0 2014-12-31   7
#
#                                                 Name   Lat   Long  Dock Count  \
# 0                           South Van Ness at Market  37.8 -122.4          19
# 1               Harry Bridges Plaza (Ferry Building)  37.8 -122.4          23
# 2      Yerba Buena Center of the Arts (3rd @ Howard)  37.8 -122.4          19
# 3                                      Market at 4th  37.8 -122.4          19
# 4                                 Powell Street BART  37.8 -122.4          19
# ...                                              ...   ...    ...         ...
# 83019                                 Market at 10th  37.8 -122.4          27
# 83020       San Francisco Caltrain (Townsend at 4th)  37.8 -122.4          19
# 83021                      Broadway St at Battery St  37.8 -122.4          15
# 83022                         Embarcadero at Sansome  37.8 -122.4          15
# 83023                           Paseo de San Antonio  37.3 -121.9          15
#
#                 City
# 0      San Francisco
# 1      San Francisco
# 2      San Francisco
# 3      San Francisco
# 4      San Francisco
# ...              ...
# 83019  San Francisco
# 83020  San Francisco
# 83021  San Francisco
# 83022  San Francisco
# 83023       San Jose
#
# [83024 rows x 12 columns]

# %% [markdown]
# Mesclando df_weather_latlong com dados da estação

# %%
df_station_weather = pd.merge(df_station_netrate, df_weather_latlong, left_on = ['Lat', 'Long', 'date'], right_on = ['Latitude', 
                                                                        'Longitude', 'Date'])
df_station_weather.head()
# Out:
#                  hour  station  trip_x  trip_y  net_rate       date  Id  \
# 0 2015-01-01 01:00:00       66       4       1         3 2015-01-01  66
# 1 2015-01-01 11:00:00       50       3       1         2 2015-01-01  50
# 2 2015-01-01 11:00:00       68       2       2         0 2015-01-01  68
# 3 2015-01-01 11:00:00       76       2       4        -2 2015-01-01  76
# 4 2015-01-01 12:00:00       39       2       2         0 2015-01-01  39
#
#                                             Name   Lat   Long  ...  \
# 0                       South Van Ness at Market  37.8 -122.4  ...
# 1           Harry Bridges Plaza (Ferry Building)  37.8 -122.4  ...
# 2  Yerba Buena Center of the Arts (3rd @ Howard)  37.8 -122.4  ...
# 3                                  Market at 4th  37.8 -122.4  ...
# 4                             Powell Street BART  37.8 -122.4  ...
#
#    Max Wind SpeedMPH Mean Wind SpeedMPH Max Gust SpeedMPH  PrecipitationIn  \
# 0               23.0                8.0              28.0              0.0
# 1               23.0                8.0              28.0              0.0
# 2               23.0                8.0              28.0              0.0
# 3               23.0                8.0              28.0              0.0
# 4               23.0                8.0              28.0              0.0
#
#    CloudCover  Events  WindDirDegrees    Zip  Latitude  Longitude
# 0         1.0     NaN            40.0  94107      37.8     -122.4
# 1         1.0     NaN            40.0  94107      37.8     -122.4
# 2         1.0     NaN            40.0  94107      37.8     -122.4
# 3         1.0     NaN            40.0  94107      37.8     -122.4
# 4         1.0     NaN            40.0  94107      37.8     -122.4
#
# [5 rows x 38 columns]

# %%
# Criar o Campo "hora do dia"
df_station_weather['hour_of_day'] = df_station_weather['hour'].apply(lambda x: int(str(x).split(' ')[-1].split(':')[0]))

# %%
df_station_weather
# Out:
#                      hour  station  trip_x  trip_y  net_rate       date  Id  \
# 0     2015-01-01 01:00:00       66       4       1         3 2015-01-01  66
# 1     2015-01-01 11:00:00       50       3       1         2 2015-01-01  50
# 2     2015-01-01 11:00:00       68       2       2         0 2015-01-01  68
# 3     2015-01-01 11:00:00       76       2       4        -2 2015-01-01  76
# 4     2015-01-01 12:00:00       39       2       2         0 2015-01-01  39
# ...                   ...      ...     ...     ...       ...        ...  ..
# 82974 2014-12-31 18:00:00       67       1       2        -1 2014-12-31  67
# 82975 2014-12-31 18:00:00       70       1       1         0 2014-12-31  70
# 82976 2014-12-31 18:00:00       82       1       1         0 2014-12-31  82
# 82977 2014-12-31 19:00:00       60       2       2         0 2014-12-31  60
# 82978 2014-12-31 09:00:00       28       2       1         1 2014-12-31  28
#
#                                                 Name   Lat   Long  ...  \
# 0                           South Van Ness at Market  37.8 -122.4  ...
# 1               Harry Bridges Plaza (Ferry Building)  37.8 -122.4  ...
# 2      Yerba Buena Center of the Arts (3rd @ Howard)  37.8 -122.4  ...
# 3                                      Market at 4th  37.8 -122.4  ...
# 4                                 Powell Street BART  37.8 -122.4  ...
# ...                                              ...   ...    ...  ...
# 82974                                 Market at 10th  37.8 -122.4  ...
# 82975       San Francisco Caltrain (Townsend at 4th)  37.8 -122.4  ...
# 82976                      Broadway St at Battery St  37.8 -122.4  ...
# 82977                         Embarcadero at Sansome  37.8 -122.4  ...
# 82978                 Mountain View Caltrain Station  37.4 -122.1  ...
#
#        Mean Wind SpeedMPH Max Gust SpeedMPH PrecipitationIn  CloudCover  \
# 0                     8.0              28.0             0.0         1.0
# 1                     8.0              28.0             0.0         1.0
# 2                     8.0              28.0             0.0         1.0
# 3                     8.0              28.0             0.0         1.0
# 4                     8.0              28.0             0.0         1.0
# ...                   ...               ...             ...         ...
# 82974                 7.0              28.0             0.0         1.0
# 82975                 7.0              28.0             0.0         1.0
# 82976                 7.0              28.0             0.0         1.0
# 82977                 7.0              28.0             0.0         1.0
# 82978                 5.0              26.0             0.0         0.0
#
#        Events  WindDirDegrees    Zip  Latitude  Longitude  hour_of_day
# 0         NaN            40.0  94107      37.8     -122.4            1
# 1         NaN            40.0  94107      37.8     -122.4           11
# 2         NaN            40.0  94107      37.8     -122.4           11
# 3         NaN            40.0  94107      37.8     -122.4           11
# 4         NaN            40.0  94107      37.8     -122.4           12
# ...       ...             ...    ...       ...        ...          ...
# 82974     NaN             8.0  94107      37.8     -122.4           18
# 82975     NaN             8.0  94107      37.8     -122.4           18
# 82976     NaN             8.0  94107      37.8     -122.4           18
# 82977     NaN             8.0  94107      37.8     -122.4           19
# 82978     NaN           335.0  94041      37.4     -122.1            9
#
# [82979 rows x 39 columns]

# %%
# Criando mais campos : Semana do ano, dia do mês, mês do ano e dia da semana
### para capturar a variação de uso do dia da semana vs fim de semana
df_station_weather['week_of_year'] = df_station_weather['Date'].dt.week
df_station_weather['day_of_month'] = df_station_weather['Date'].apply(lambda x: str(x).split('-')[-1].split(' ')[0])
df_station_weather['month_of_year'] = df_station_weather['Date'].dt.month
df_station_weather['day_of_week'] = df_station_weather['Date'].dt.dayofweek
# Out:
# <ipython-input-49-236b6f11cf74>:3: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df_station_weather['week_of_year'] = df_station_weather['Date'].dt.week

# %%
df_station_weather.head()
# Out:
#                  hour  station  trip_x  trip_y  net_rate       date  Id  \
# 0 2015-01-01 01:00:00       66       4       1         3 2015-01-01  66
# 1 2015-01-01 11:00:00       50       3       1         2 2015-01-01  50
# 2 2015-01-01 11:00:00       68       2       2         0 2015-01-01  68
# 3 2015-01-01 11:00:00       76       2       4        -2 2015-01-01  76
# 4 2015-01-01 12:00:00       39       2       2         0 2015-01-01  39
#
#                                             Name   Lat   Long  ...  Events  \
# 0                       South Van Ness at Market  37.8 -122.4  ...     NaN
# 1           Harry Bridges Plaza (Ferry Building)  37.8 -122.4  ...     NaN
# 2  Yerba Buena Center of the Arts (3rd @ Howard)  37.8 -122.4  ...     NaN
# 3                                  Market at 4th  37.8 -122.4  ...     NaN
# 4                             Powell Street BART  37.8 -122.4  ...     NaN
#
#   WindDirDegrees    Zip  Latitude  Longitude  hour_of_day  week_of_year  \
# 0           40.0  94107      37.8     -122.4            1             1
# 1           40.0  94107      37.8     -122.4           11             1
# 2           40.0  94107      37.8     -122.4           11             1
# 3           40.0  94107      37.8     -122.4           11             1
# 4           40.0  94107      37.8     -122.4           12             1
#
#    day_of_month  month_of_year  day_of_week
# 0            01              1            3
# 1            01              1            3
# 2            01              1            3
# 3            01              1            3
# 4            01              1            3
#
# [5 rows x 43 columns]

# %%
cols_to_remove = ['hour', 'trip_x', 'trip_y', 'date', 'Lat', 'Long', 'station', 'Zip', 'Id', 'Name', 'City', 'Date', 'Events']

df_final = df_station_weather.drop(columns=cols_to_remove)
df_final
# Out:
#        net_rate  Dock Count  Max TemperatureF  Mean TemperatureF  \
# 0             3          19              56.0               47.0
# 1             2          23              56.0               47.0
# 2             0          19              56.0               47.0
# 3            -2          19              56.0               47.0
# 4             0          19              56.0               47.0
# ...         ...         ...               ...                ...
# 82974        -1          27              59.0               48.0
# 82975         0          19              59.0               48.0
# 82976         0          15              59.0               48.0
# 82977         0          15              59.0               48.0
# 82978         1          23              57.0               47.0
#
#        Min TemperatureF  Max Dew PointF  MeanDew PointF  Min DewpointF  \
# 0                  38.0            27.0            20.0           14.0
# 1                  38.0            27.0            20.0           14.0
# 2                  38.0            27.0            20.0           14.0
# 3                  38.0            27.0            20.0           14.0
# 4                  38.0            27.0            20.0           14.0
# ...                 ...             ...             ...            ...
# 82974              36.0            36.0            17.0            5.0
# 82975              36.0            36.0            17.0            5.0
# 82976              36.0            36.0            17.0            5.0
# 82977              36.0            36.0            17.0            5.0
# 82978              37.0            23.0            15.0            8.0
#
#        Max Humidity  Mean Humidity  ...  PrecipitationIn  CloudCover  \
# 0              54.0           37.0  ...              0.0         1.0
# 1              54.0           37.0  ...              0.0         1.0
# 2              54.0           37.0  ...              0.0         1.0
# 3              54.0           37.0  ...              0.0         1.0
# 4              54.0           37.0  ...              0.0         1.0
# ...             ...            ...  ...              ...         ...
# 82974          67.0           41.0  ...              0.0         1.0
# 82975          67.0           41.0  ...              0.0         1.0
# 82976          67.0           41.0  ...              0.0         1.0
# 82977          67.0           41.0  ...              0.0         1.0
# 82978          54.0           35.0  ...              0.0         0.0
#
#        WindDirDegrees  Latitude  Longitude  hour_of_day  week_of_year  \
# 0                40.0      37.8     -122.4            1             1
# 1                40.0      37.8     -122.4           11             1
# 2                40.0      37.8     -122.4           11             1
# 3                40.0      37.8     -122.4           11             1
# 4                40.0      37.8     -122.4           12             1
# ...               ...       ...        ...          ...           ...
# 82974             8.0      37.8     -122.4           18             1
# 82975             8.0      37.8     -122.4           18             1
# 82976             8.0      37.8     -122.4           18             1
# 82977             8.0      37.8     -122.4           19             1
# 82978           335.0      37.4     -122.1            9             1
#
#        day_of_month  month_of_year  day_of_week
# 0                01              1            3
# 1                01              1            3
# 2                01              1            3
# 3                01              1            3
# 4                01              1            3
# ...             ...            ...          ...
# 82974            31             12            2
# 82975            31             12            2
# 82976            31             12            2
# 82977            31             12            2
# 82978            31             12            2
#
# [82979 rows x 30 columns]

# %%
df_final.head()
# Out:
#    net_rate  Dock Count  Max TemperatureF  Mean TemperatureF  \
# 0         3          19              56.0               47.0
# 1         2          23              56.0               47.0
# 2         0          19              56.0               47.0
# 3        -2          19              56.0               47.0
# 4         0          19              56.0               47.0
#
#    Min TemperatureF  Max Dew PointF  MeanDew PointF  Min DewpointF  \
# 0              38.0            27.0            20.0           14.0
# 1              38.0            27.0            20.0           14.0
# 2              38.0            27.0            20.0           14.0
# 3              38.0            27.0            20.0           14.0
# 4              38.0            27.0            20.0           14.0
#
#    Max Humidity  Mean Humidity  ...  PrecipitationIn  CloudCover  \
# 0          54.0           37.0  ...              0.0         1.0
# 1          54.0           37.0  ...              0.0         1.0
# 2          54.0           37.0  ...              0.0         1.0
# 3          54.0           37.0  ...              0.0         1.0
# 4          54.0           37.0  ...              0.0         1.0
#
#    WindDirDegrees  Latitude  Longitude  hour_of_day  week_of_year  \
# 0            40.0      37.8     -122.4            1             1
# 1            40.0      37.8     -122.4           11             1
# 2            40.0      37.8     -122.4           11             1
# 3            40.0      37.8     -122.4           11             1
# 4            40.0      37.8     -122.4           12             1
#
#    day_of_month  month_of_year  day_of_week
# 0            01              1            3
# 1            01              1            3
# 2            01              1            3
# 3            01              1            3
# 4            01              1            3
#
# [5 rows x 30 columns]

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 82979 entries, 0 to 82978
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   net_rate                   82979 non-null  int64
#  1   Dock Count                 82979 non-null  int64
#  2   Max TemperatureF           82970 non-null  float64
#  3   Mean TemperatureF          82970 non-null  float64
#  4   Min TemperatureF           82970 non-null  float64
#  5   Max Dew PointF             82932 non-null  float64
#  6   MeanDew PointF             82932 non-null  float64
#  7   Min DewpointF              82932 non-null  float64
#  8   Max Humidity               82932 non-null  float64
#  9   Mean Humidity              82932 non-null  float64
#  10  Min Humidity               82932 non-null  float64
#  11  Max Sea Level PressureIn   82976 non-null  float64
#  12  Mean Sea Level PressureIn  82976 non-null  float64
#  13  Min Sea Level PressureIn   82976 non-null  float64
#  14  Max VisibilityMiles        82973 non-null  float64
#  15  Mean VisibilityMiles       82973 non-null  float64
#  16  Min VisibilityMiles        82973 non-null  float64
#  17  Max Wind SpeedMPH          82976 non-null  float64
#  18  Mean Wind SpeedMPH         82976 non-null  float64
#  19  Max Gust SpeedMPH          80762 non-null  float64
#  20  PrecipitationIn            82976 non-null  float64
#  21  CloudCover                 82976 non-null  float64
#  22  WindDirDegrees             82976 non-null  float64
#  23  Latitude                   82979 non-null  float64
#  24  Longitude                  82979 non-null  float64
#  25  hour_of_day                82979 non-null  int64
#  26  week_of_year               82979 non-null  int64
#  27  day_of_month               82979 non-null  object
#  28  month_of_year              82979 non-null  int64
#  29  day_of_week                82979 non-null  int64
# dtypes: float64(23), int64(6), object(1)
# memory usage: 19.6+ MB

# %%
df_corr = df_final.corr()
df_corr
# Out:
#                            net_rate  Dock Count  Max TemperatureF  \
# net_rate                   1.000000   -0.002124          0.001432
# Dock Count                -0.002124    1.000000         -0.001670
# Max TemperatureF           0.001432   -0.001670          1.000000
# Mean TemperatureF         -0.000180    0.000346          0.893801
# Min TemperatureF          -0.001667    0.002583          0.557964
# Max Dew PointF             0.002298    0.001119          0.646272
# MeanDew PointF             0.001294    0.003012          0.515157
# Min DewpointF              0.000384    0.003973          0.394650
# Max Humidity               0.001249   -0.001883         -0.175050
# Mean Humidity             -0.000173    0.004656         -0.459311
# Min Humidity              -0.000794    0.006288         -0.513728
# Max Sea Level PressureIn   0.002192   -0.004515         -0.427068
# Mean Sea Level PressureIn  0.001952   -0.006034         -0.397840
# Min Sea Level PressureIn   0.001686   -0.006424         -0.373629
# Max VisibilityMiles       -0.000940   -0.018287          0.080484
# Mean VisibilityMiles      -0.001797   -0.004759          0.278280
# Min VisibilityMiles       -0.002589   -0.002784          0.264533
# Max Wind SpeedMPH         -0.004732    0.002489          0.096253
# Mean Wind SpeedMPH        -0.006002    0.005611          0.013346
# Max Gust SpeedMPH         -0.003070    0.008619          0.129158
# PrecipitationIn           -0.002176    0.009104         -0.169439
# CloudCover                -0.001754    0.007044         -0.379574
# WindDirDegrees            -0.001063   -0.005533          0.364062
# Latitude                   0.007006    0.035928         -0.150596
# Longitude                 -0.006575   -0.030639          0.149113
# hour_of_day                0.061147   -0.020969          0.001533
# week_of_year               0.002870    0.010631          0.144951
# month_of_year              0.002735    0.011042          0.104562
# day_of_week               -0.003234   -0.011463         -0.012428
#
#                            Mean TemperatureF  Min TemperatureF  \
# net_rate                           -0.000180         -0.001667
# Dock Count                          0.000346          0.002583
# Max TemperatureF                    0.893801          0.557964
# Mean TemperatureF                   1.000000          0.869253
# Min TemperatureF                    0.869253          1.000000
# Max Dew PointF                      0.783468          0.745529
# MeanDew PointF                      0.743764          0.817013
# Min DewpointF                       0.672357          0.816957
# Max Humidity                       -0.201315         -0.178846
# Mean Humidity                      -0.247680          0.050819
# Min Humidity                       -0.219085          0.163730
# Max Sea Level PressureIn           -0.604843         -0.651669
# Mean Sea Level PressureIn          -0.570139         -0.618948
# Min Sea Level PressureIn           -0.535182         -0.579888
# Max VisibilityMiles                 0.094922          0.092565
# Mean VisibilityMiles                0.263775          0.184741
# Min VisibilityMiles                 0.213726          0.103285
# Max Wind SpeedMPH                   0.284019          0.415211
# Mean Wind SpeedMPH                  0.288813          0.513728
# Max Gust SpeedMPH                   0.267540          0.349399
# PrecipitationIn                    -0.080645          0.032650
# CloudCover                         -0.051449          0.326834
# WindDirDegrees                      0.322053          0.201242
# Latitude                           -0.113867         -0.045207
# Longitude                           0.110159          0.039357
# hour_of_day                         0.000053         -0.001457
# week_of_year                        0.233703          0.277386
# month_of_year                       0.185542          0.231028
# day_of_week                         0.006504          0.025352
#
#                            Max Dew PointF  MeanDew PointF  Min DewpointF  \
# net_rate                         0.002298        0.001294       0.000384
# Dock Count                       0.001119        0.003012       0.003973
# Max TemperatureF                 0.646272        0.515157       0.394650
# Mean TemperatureF                0.783468        0.743764       0.672357
# Min TemperatureF                 0.745529        0.817013       0.816957
# Max Dew PointF                   1.000000        0.930410       0.813220
# MeanDew PointF                   0.930410        1.000000       0.954161
# Min DewpointF                    0.813220        0.954161       1.000000
# Max Humidity                     0.258050        0.267566       0.201940
# Mean Humidity                    0.256252        0.405181       0.454781
# Min Humidity                     0.196570        0.389319       0.490539
# Max Sea Level PressureIn        -0.449769       -0.536564      -0.566247
# Mean Sea Level PressureIn       -0.418938       -0.500895      -0.527482
# Min Sea Level PressureIn        -0.384020       -0.460579      -0.484652
# Max VisibilityMiles              0.061709        0.053891       0.047561
# Mean VisibilityMiles            -0.017136       -0.031111       0.007000
# Min VisibilityMiles             -0.083954       -0.110695      -0.086260
# Max Wind SpeedMPH                0.097984        0.161075       0.201006
# Mean Wind SpeedMPH               0.086622        0.201765       0.289291
# Max Gust SpeedMPH                0.118561        0.129738       0.131092
# PrecipitationIn                  0.057768        0.058213       0.052055
# CloudCover                       0.122636        0.287002       0.376358
# WindDirDegrees                   0.234462        0.198537       0.146959
# Latitude                        -0.042162        0.001023       0.025494
# Longitude                        0.032158       -0.008378      -0.031104
# hour_of_day                      0.002657        0.000729      -0.000909
# week_of_year                     0.340919        0.334660       0.299323
# month_of_year                    0.286242        0.266215       0.234799
# day_of_week                      0.032853        0.056123       0.060859
#
#                            Max Humidity  Mean Humidity  ...  \
# net_rate                       0.001249      -0.000173  ...
# Dock Count                    -0.001883       0.004656  ...
# Max TemperatureF              -0.175050      -0.459311  ...
# Mean TemperatureF             -0.201315      -0.247680  ...
# Min TemperatureF              -0.178846       0.050819  ...
# Max Dew PointF                 0.258050       0.256252  ...
# MeanDew PointF                 0.267566       0.405181  ...
# Min DewpointF                  0.201940       0.454781  ...
# Max Humidity                   1.000000       0.722492  ...
# Mean Humidity                  0.722492       1.000000  ...
# Min Humidity                   0.411359       0.924313  ...
# Max Sea Level PressureIn       0.101286      -0.011268  ...
# Mean Sea Level PressureIn      0.095914      -0.010272  ...
# Min Sea Level PressureIn       0.088353      -0.002499  ...
# Max VisibilityMiles           -0.075334      -0.079185  ...
# Mean VisibilityMiles          -0.468700      -0.486169  ...
# Min VisibilityMiles           -0.481666      -0.528732  ...
# Max Wind SpeedMPH             -0.197562      -0.086456  ...
# Mean Wind SpeedMPH            -0.313569      -0.046267  ...
# Max Gust SpeedMPH             -0.174789      -0.123293  ...
# PrecipitationIn                0.148507       0.233070  ...
# CloudCover                     0.097524       0.516284  ...
# WindDirDegrees                -0.048722      -0.171701  ...
# Latitude                       0.069851       0.149401  ...
# Longitude                     -0.069095      -0.151432  ...
# hour_of_day                    0.006099       0.001785  ...
# week_of_year                   0.047410       0.126328  ...
# month_of_year                  0.037001       0.105129  ...
# day_of_week                    0.083016       0.070953  ...
#
#                            Max Gust SpeedMPH  PrecipitationIn  CloudCover  \
# net_rate                           -0.003070        -0.002176   -0.001754
# Dock Count                          0.008619         0.009104    0.007044
# Max TemperatureF                    0.129158        -0.169439   -0.379574
# Mean TemperatureF                   0.267540        -0.080645   -0.051449
# Min TemperatureF                    0.349399         0.032650    0.326834
# Max Dew PointF                      0.118561         0.057768    0.122636
# MeanDew PointF                      0.129738         0.058213    0.287002
# Min DewpointF                       0.131092         0.052055    0.376358
# Max Humidity                       -0.174789         0.148507    0.097524
# Mean Humidity                      -0.123293         0.233070    0.516284
# Min Humidity                       -0.064893         0.229649    0.631114
# Max Sea Level PressureIn           -0.352541        -0.090636   -0.197286
# Mean Sea Level PressureIn          -0.375207        -0.153908   -0.197096
# Min Sea Level PressureIn           -0.396403        -0.185707   -0.189146
# Max VisibilityMiles                 0.072932         0.002933   -0.033450
# Mean VisibilityMiles                0.107814        -0.256613   -0.157840
# Min VisibilityMiles                 0.062007        -0.307116   -0.216310
# Max Wind SpeedMPH                   0.751184         0.205723    0.213156
# Mean Wind SpeedMPH                  0.599185         0.157152    0.314913
# Max Gust SpeedMPH                   1.000000         0.182787    0.102022
# PrecipitationIn                     0.182787         1.000000    0.238907
# CloudCover                          0.102022         0.238907    1.000000
# WindDirDegrees                      0.039043        -0.236878   -0.245398
# Latitude                            0.071040         0.016781    0.147616
# Longitude                          -0.069757        -0.015249   -0.133251
# hour_of_day                        -0.006240         0.001476    0.002136
# week_of_year                        0.054585         0.084549    0.137659
# month_of_year                       0.072970         0.084207    0.126882
# day_of_week                         0.017035        -0.017374    0.052972
#
#                            WindDirDegrees  Latitude  Longitude  hour_of_day  \
# net_rate                        -0.001063  0.007006  -0.006575     0.061147
# Dock Count                      -0.005533  0.035928  -0.030639    -0.020969
# Max TemperatureF                 0.364062 -0.150596   0.149113     0.001533
# Mean TemperatureF                0.322053 -0.113867   0.110159     0.000053
# Min TemperatureF                 0.201242 -0.045207   0.039357    -0.001457
# Max Dew PointF                   0.234462 -0.042162   0.032158     0.002657
# MeanDew PointF                   0.198537  0.001023  -0.008378     0.000729
# Min DewpointF                    0.146959  0.025494  -0.031104    -0.000909
# Max Humidity                    -0.048722  0.069851  -0.069095     0.006099
# Mean Humidity                   -0.171701  0.149401  -0.151432     0.001785
# Min Humidity                    -0.197610  0.162939  -0.165686    -0.000903
# Max Sea Level PressureIn        -0.172906  0.017877  -0.017895     0.005390
# Mean Sea Level PressureIn       -0.135940  0.017442  -0.018095     0.003612
# Min Sea Level PressureIn        -0.093244  0.016244  -0.017666     0.002176
# Max VisibilityMiles             -0.014571 -0.110854   0.061562     0.008775
# Mean VisibilityMiles             0.086668 -0.059985   0.052193    -0.000170
# Min VisibilityMiles              0.147679 -0.085448   0.081693    -0.001504
# Max Wind SpeedMPH                0.029901  0.074475  -0.071580    -0.006427
# Mean Wind SpeedMPH               0.033752  0.155814  -0.150684    -0.010869
# Max Gust SpeedMPH                0.039043  0.071040  -0.069757    -0.006240
# PrecipitationIn                 -0.236878  0.016781  -0.015249     0.001476
# CloudCover                      -0.245398  0.147616  -0.133251     0.002136
# WindDirDegrees                   1.000000 -0.024090   0.020293    -0.000540
# Latitude                        -0.024090  1.000000  -0.985881     0.001046
# Longitude                        0.020293 -0.985881   1.000000    -0.000765
# hour_of_day                     -0.000540  0.001046  -0.000765     1.000000
# week_of_year                    -0.001321 -0.000442   0.000198     0.001610
# month_of_year                   -0.031196  0.002343  -0.002428    -0.000664
# day_of_week                     -0.012036  0.004252  -0.002902     0.015647
#
#                            week_of_year  month_of_year  day_of_week
# net_rate                       0.002870       0.002735    -0.003234
# Dock Count                     0.010631       0.011042    -0.011463
# Max TemperatureF               0.144951       0.104562    -0.012428
# Mean TemperatureF              0.233703       0.185542     0.006504
# Min TemperatureF               0.277386       0.231028     0.025352
# Max Dew PointF                 0.340919       0.286242     0.032853
# MeanDew PointF                 0.334660       0.266215     0.056123
# Min DewpointF                  0.299323       0.234799     0.060859
# Max Humidity                   0.047410       0.037001     0.083016
# Mean Humidity                  0.126328       0.105129     0.070953
# Min Humidity                   0.147308       0.125547     0.047064
# Max Sea Level PressureIn      -0.161940      -0.142901    -0.103019
# Mean Sea Level PressureIn     -0.157928      -0.143309    -0.113540
# Min Sea Level PressureIn      -0.151983      -0.139378    -0.126719
# Max VisibilityMiles            0.072669       0.073044     0.000320
# Mean VisibilityMiles          -0.031079      -0.030877    -0.048500
# Min VisibilityMiles           -0.076431      -0.074693    -0.019197
# Max Wind SpeedMPH             -0.039522      -0.022277     0.081872
# Mean Wind SpeedMPH             0.008861       0.007005     0.002181
# Max Gust SpeedMPH              0.054585       0.072970     0.017035
# PrecipitationIn                0.084549       0.084207    -0.017374
# CloudCover                     0.137659       0.126882     0.052972
# WindDirDegrees                -0.001321      -0.031196    -0.012036
# Latitude                      -0.000442       0.002343     0.004252
# Longitude                      0.000198      -0.002428    -0.002902
# hour_of_day                    0.001610      -0.000664     0.015647
# week_of_year                   1.000000       0.967133    -0.016452
# month_of_year                  0.967133       1.000000    -0.003965
# day_of_week                   -0.016452      -0.003965     1.000000
#
# [29 rows x 29 columns]

# %%
import seaborn as sns
ax = sns.heatmap(df_corr)

# %%
df_final.columns
# Out:
# Index(['net_rate', 'Dock Count', 'Max TemperatureF', 'Mean TemperatureF',
#        'Min TemperatureF', 'Max Dew PointF', 'MeanDew PointF', 'Min DewpointF',
#        'Max Humidity', 'Mean Humidity', 'Min Humidity',
#        'Max Sea Level PressureIn', 'Mean Sea Level PressureIn',
#        'Min Sea Level PressureIn', 'Max VisibilityMiles',
#        'Mean VisibilityMiles', 'Min VisibilityMiles', 'Max Wind SpeedMPH',
#        'Mean Wind SpeedMPH', 'Max Gust SpeedMPH', 'PrecipitationIn',
#        'CloudCover', 'WindDirDegrees', 'Latitude', 'Longitude', 'hour_of_day',
#        'week_of_year', 'day_of_month', 'month_of_year', 'day_of_week'],
#       dtype='object')

# %%
### Os atributos mínimo e máximo foram removidos devido à alta correlação com o atributo 'Média'
df_final = df_final[[k for k in df_final.columns if ('Max' not in k) and ('Min' not in k)]]

# %%
df_final
# Out:
#        net_rate  Dock Count  Mean TemperatureF  MeanDew PointF  Mean Humidity  \
# 0             3          19               47.0            20.0           37.0
# 1             2          23               47.0            20.0           37.0
# 2             0          19               47.0            20.0           37.0
# 3            -2          19               47.0            20.0           37.0
# 4             0          19               47.0            20.0           37.0
# ...         ...         ...                ...             ...            ...
# 82974        -1          27               48.0            17.0           41.0
# 82975         0          19               48.0            17.0           41.0
# 82976         0          15               48.0            17.0           41.0
# 82977         0          15               48.0            17.0           41.0
# 82978         1          23               47.0            15.0           35.0
#
#        Mean Sea Level PressureIn  Mean VisibilityMiles  Mean Wind SpeedMPH  \
# 0                          30.13                  10.0                 8.0
# 1                          30.13                  10.0                 8.0
# 2                          30.13                  10.0                 8.0
# 3                          30.13                  10.0                 8.0
# 4                          30.13                  10.0                 8.0
# ...                          ...                   ...                 ...
# 82974                      30.17                  10.0                 7.0
# 82975                      30.17                  10.0                 7.0
# 82976                      30.17                  10.0                 7.0
# 82977                      30.17                  10.0                 7.0
# 82978                      30.19                  10.0                 5.0
#
#        PrecipitationIn  CloudCover  WindDirDegrees  Latitude  Longitude  \
# 0                  0.0         1.0            40.0      37.8     -122.4
# 1                  0.0         1.0            40.0      37.8     -122.4
# 2                  0.0         1.0            40.0      37.8     -122.4
# 3                  0.0         1.0            40.0      37.8     -122.4
# 4                  0.0         1.0            40.0      37.8     -122.4
# ...                ...         ...             ...       ...        ...
# 82974              0.0         1.0             8.0      37.8     -122.4
# 82975              0.0         1.0             8.0      37.8     -122.4
# 82976              0.0         1.0             8.0      37.8     -122.4
# 82977              0.0         1.0             8.0      37.8     -122.4
# 82978              0.0         0.0           335.0      37.4     -122.1
#
#        hour_of_day  week_of_year day_of_month  month_of_year  day_of_week
# 0                1             1           01              1            3
# 1               11             1           01              1            3
# 2               11             1           01              1            3
# 3               11             1           01              1            3
# 4               12             1           01              1            3
# ...            ...           ...          ...            ...          ...
# 82974           18             1           31             12            2
# 82975           18             1           31             12            2
# 82976           18             1           31             12            2
# 82977           19             1           31             12            2
# 82978            9             1           31             12            2
#
# [82979 rows x 18 columns]

# %%
df_corr = df_final.corr()
df_corr
ax = sns.heatmap(df_corr)

# %% [markdown]
# Análise exploratória de dados
# A taxa líquida é altamente impactada pela temperatura extrema

# %%
plt.scatter(x = df_final['Mean TemperatureF'], y = df_final['net_rate']);

# %%
plt.scatter(x = df_final['Mean Wind SpeedMPH'], y = df_final['net_rate']);

# %%
plt.scatter(df_final['day_of_week'], df_final['net_rate']);

# %% [markdown]
# Observamos que a taxa líquida é menor por volta da noite, da meia-noite às 5h.

# %%
plt.scatter(np.sort(df_final['hour_of_day']), df_final['net_rate']);

# %% [markdown]
# Distribuição de taxa líquida

# %%
plt.hist(df_final['net_rate'], bins = 50);

# %% [markdown]
# ### Separando os dados de Treino e Teste

# %%
#Arredondando o campo
df_final['day_of_month'] = df_final['day_of_month'].apply(lambda x: int(x))
df_final
# Out:
# <ipython-input-67-aff9e7c2f0d6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['day_of_month'] = df_final['day_of_month'].apply(lambda x: int(x))
#        net_rate  Dock Count  Mean TemperatureF  MeanDew PointF  Mean Humidity  \
# 0             3          19               47.0            20.0           37.0
# 1             2          23               47.0            20.0           37.0
# 2             0          19               47.0            20.0           37.0
# 3            -2          19               47.0            20.0           37.0
# 4             0          19               47.0            20.0           37.0
# ...         ...         ...                ...             ...            ...
# 82974        -1          27               48.0            17.0           41.0
# 82975         0          19               48.0            17.0           41.0
# 82976         0          15               48.0            17.0           41.0
# 82977         0          15               48.0            17.0           41.0
# 82978         1          23               47.0            15.0           35.0
#
#        Mean Sea Level PressureIn  Mean VisibilityMiles  Mean Wind SpeedMPH  \
# 0                          30.13                  10.0                 8.0
# 1                          30.13                  10.0                 8.0
# 2                          30.13                  10.0                 8.0
# 3                          30.13                  10.0                 8.0
# 4                          30.13                  10.0                 8.0
# ...                          ...                   ...                 ...
# 82974                      30.17                  10.0                 7.0
# 82975                      30.17                  10.0                 7.0
# 82976                      30.17                  10.0                 7.0
# 82977                      30.17                  10.0                 7.0
# 82978                      30.19                  10.0                 5.0
#
#        PrecipitationIn  CloudCover  WindDirDegrees  Latitude  Longitude  \
# 0                  0.0         1.0            40.0      37.8     -122.4
# 1                  0.0         1.0            40.0      37.8     -122.4
# 2                  0.0         1.0            40.0      37.8     -122.4
# 3                  0.0         1.0            40.0      37.8     -122.4
# 4                  0.0         1.0            40.0      37.8     -122.4
# ...                ...         ...             ...       ...        ...
# 82974              0.0         1.0             8.0      37.8     -122.4
# 82975              0.0         1.0             8.0      37.8     -122.4
# 82976              0.0         1.0             8.0      37.8     -122.4
# 82977              0.0         1.0             8.0      37.8     -122.4
# 82978              0.0         0.0           335.0      37.4     -122.1
#
#        hour_of_day  week_of_year  day_of_month  month_of_year  day_of_week
# 0                1             1             1              1            3
# 1               11             1             1              1            3
# 2               11             1             1              1            3
# 3               11             1             1              1            3
# 4               12             1             1              1            3
# ...            ...           ...           ...            ...          ...
# 82974           18             1            31             12            2
# 82975           18             1            31             12            2
# 82976           18             1            31             12            2
# 82977           19             1            31             12            2
# 82978            9             1            31             12            2
#
# [82979 rows x 18 columns]

# %%
### Treino e teste a divisão com 30% do tamanho do teste
y = df_final['net_rate']
X = df_final.drop(columns='net_rate')

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 4)

# %%
X_train.head()
# Out:
#        Dock Count  Mean TemperatureF  MeanDew PointF  Mean Humidity  \
# 75479          23               72.0            55.0           62.0
# 73990          19               57.0            48.0           69.0
# 42246          15               65.0            36.0           47.0
# 74429          19               53.0            46.0           73.0
# 57098          19               66.0            56.0           70.0
#
#        Mean Sea Level PressureIn  Mean VisibilityMiles  Mean Wind SpeedMPH  \
# 75479                      29.87                  10.0                 6.0
# 73990                      30.05                  10.0                 4.0
# 42246                      30.02                  10.0                 8.0
# 74429                      30.22                  10.0                 3.0
# 57098                      29.88                  10.0                11.0
#
#        PrecipitationIn  CloudCover  WindDirDegrees  Latitude  Longitude  \
# 75479              0.0         0.0           291.0      37.8     -122.4
# 73990              0.0         2.0           300.0      37.8     -122.4
# 42246              0.0         0.0           329.0      37.8     -122.4
# 74429              0.0         2.0           265.0      37.8     -122.4
# 57098              0.0         6.0           262.0      37.8     -122.4
#
#        hour_of_day  week_of_year  day_of_month  month_of_year  day_of_week
# 75479           10            31            28              7            1
# 73990           17            44            27             10            0
# 42246           13            16            16              4            3
# 74429           19             5            28              1            2
# 57098           16            34            21              8            4

# %%
X_train.describe().T
# Out:
#                              count        mean        std     min     25%  \
# Dock Count                 58085.0   19.557321   4.121457   11.00   15.00
# Mean TemperatureF          58077.0   61.091947   6.039059   41.00   57.00
# MeanDew PointF             58046.0   50.409796   6.062237   13.00   47.00
# Mean Humidity              58046.0   70.392172   8.707469   29.00   66.00
# Mean Sea Level PressureIn  58082.0   30.012310   0.127399   29.63   29.91
# Mean VisibilityMiles       58081.0    9.455553   1.163565    4.00    9.00
# Mean Wind SpeedMPH         58082.0    7.624100   3.356100    0.00    5.00
# PrecipitationIn            58082.0    0.023468   0.134251    0.00    0.00
# CloudCover                 58082.0    3.951345   2.259863    0.00    2.00
# WindDirDegrees             58082.0  258.216969  66.902045    0.00  250.00
# Latitude                   58085.0   37.765581   0.120413   37.30   37.80
# Longitude                  58085.0 -122.369700   0.109818 -122.40 -122.40
# hour_of_day                58085.0   13.289903   4.382159    0.00    9.00
# week_of_year               58085.0   26.335474  14.420454    1.00   14.00
# day_of_month               58085.0   15.606663   8.697655    1.00    8.00
# month_of_year              58085.0    6.437686   3.329530    1.00    4.00
# day_of_week                58085.0    2.636171   1.865798    0.00    1.00
#
#                               50%     75%     max
# Dock Count                  19.00   23.00   27.00
# Mean TemperatureF           60.00   66.00   82.00
# MeanDew PointF              51.00   55.00   63.00
# Mean Humidity               71.00   75.00   95.00
# Mean Sea Level PressureIn   29.99   30.09   30.41
# Mean VisibilityMiles        10.00   10.00   19.00
# Mean Wind SpeedMPH           8.00   10.00   22.00
# PrecipitationIn              0.00    0.00    3.23
# CloudCover                   4.00    6.00    8.00
# WindDirDegrees             273.00  297.00  360.00
# Latitude                    37.80   37.80   37.80
# Longitude                 -122.40 -122.40 -121.90
# hour_of_day                 13.00   17.00   23.00
# week_of_year                27.00   39.00   52.00
# day_of_month                16.00   23.00   31.00
# month_of_year                6.00    9.00   12.00
# day_of_week                  3.00    4.00    6.00

# %%
#limpeza final
X_train.fillna(0, inplace=True)
X_test.fillna(0, inplace=True)
# Out:
# C:\Users\Silvio\anaconda3\lib\site-packages\pandas\core\frame.py:4317: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %% [markdown]
# # 4° Máquina Preditiva - Baseline

# %% [markdown]
# ### **Regressão linear**

# %%
### Máquina Preditiva com Regressão Linear - Treina e Faz novas Previsões
reg_obj = LinearRegression().fit(X_train, y_train)
y_train_pred = reg_obj.predict(X_train)
y_test_pred = reg_obj.predict(X_test)

# %% [markdown]
# # 5° Avaliação da Máquina Preditiva - Baseline

# %% [markdown]
# ## RMSE - Métrica de Avaliação: Quanto menor melhor....

# %%
#Valor do RMSE dados de treino
np.sqrt(mean_squared_error(y_train, y_train_pred))
# Out:
# 3.765563611537702

# %%
#Valor do RMSE dados de teste
np.sqrt(mean_squared_error(y_test, y_test_pred))
# Out:
# 3.8242525268436296

# %% [markdown]
# ## Máquina Preditiva Modelo Final

# %% [markdown]
# ### **Decision Tree**

# %%
reg_DT = DecisionTreeRegressor(random_state=4).fit(X_train, y_train)

y_train_pred_DT = reg_DT.predict(X_train)
y_test_pred_DT = reg_DT.predict(X_test)

np.sqrt(mean_squared_error(y_train, y_train_pred_DT)), np.sqrt(mean_squared_error(y_test, y_test_pred_DT))
# Out:
# (3.039673262915482, 4.1029224084149165)

# %%
### podando a árvore de decisão definindo max_depth = 3
reg_DT = DecisionTreeRegressor(max_depth = 3, random_state=7).fit(X_train, y_train)

y_train_pred_DT = reg_DT.predict(X_train)
y_test_pred_DT = reg_DT.predict(X_test)

np.sqrt(mean_squared_error(y_train, y_train_pred_DT)), np.sqrt(mean_squared_error(y_test, y_test_pred_DT))
# Out:
# (3.628563724180922, 3.6834277151482726)

# %% [markdown]
# # **Resumão**
#
# * tentei dar uma ideia intuitiva Sobre Como as Fintechs nascem.
# * Importância da Geração de Hipóteses
# * Utilização de Fontes Dados externas
# * Engenharia de Atributos (criação de Variáveis)
#
#
#
# ![](https://thumbs.gfycat.com/GentleDisloyalEider-max-1mb.gif)

# %% [markdown]
# # Fim
